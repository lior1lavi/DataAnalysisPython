# %%
word = open('words','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='words' mode='r' encoding='cp1255'>

# %%
wordline = word.readlines

# %% [markdown]
# wordline[1:10]

# %%
wordline
# Out:
# <function TextIOWrapper.readlines(hint=-1, /)>

# %%
wordline = word.readlines()

# %%
wordline[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
len(wordline)
# Out:
# 235886

# %%
wordlean = [word.strip().lower() for word in wordline]

# %%
wordlean
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
#  'abashedness',
#  'abashless',
#  'abashlessly',
#  'abashment',
#  'abasia',
#  'abasic',
#  'abask',
#  'abassin',
#  'abastardize',
#  'abatable',
#  'abate',
#  'abatement',
#  'abater',
#  'abatis',
#  'abatised',
#  'abaton',
#  'abator',
#  'abattoir',
#  'abatua',
#  'abature',
#  'abave',
#  'abaxial',
#  'abaxile',
#  'abaze',
#  'abb',
#  'abba',
#  'abbacomes',
#  'abbacy',
#  'abbadide',
#  'abbas',
#  'abbasi',
#  'abbassi',
#  'abbasside',
#  'abbatial',
#  'abbatical',
#  'abbess',
#  'abbey',
#  'abbeystede',
#  'abbie',
#  'abbot',
#  'abbotcy',
#  'abbotnullius',
#  'abbotship',
#  'abbreviate',
#  'abbreviately',
#  'abbreviation',
#  'abbreviator',
#  'abbreviatory',
#  'abbreviature',
#  'abby',
#  'abcoulomb',
#  'abdal',
#  'abdat',
#  'abderian',
#  'abderite',
#  'abdest',
#  'abdicable',
#  'abdicant',
#  'abdicate',
#  'abdication',
#  'abdicative',
#  'abdicator',
#  'abdiel',
#  'abditive',
#  'abditory',
#  'abdomen',
#  'abdominal',
#  'abdominales',
#  'abdominalian',
#  'abdominally',
#  'abdominoanterior',
#  'abdominocardiac',
#  'abdominocentesis',
#  'abdominocystic',
#  'abdominogenital',
#  'abdominohysterectomy',
#  'abdominohysterotomy',
#  'abdominoposterior',
#  'abdominoscope',
#  'abdominoscopy',
#  'abdominothoracic',
#  'abdominous',
#  'abdominovaginal',
#  'abdominovesical',
#  'abduce',
#  'abducens',
#  'abducent',
#  'abduct',
#  'abduction',
#  'abductor',
#  'abe',
#  'abeam',
#  'abear',
#  'abearance',
#  'abecedarian',
#  'abecedarium',
#  'abecedary',
#  'abed',
#  'abeigh',
#  'abel',
#  'abele',
#  'abelia',
#  'abelian',
#  'abelicea',
#  'abelite',
#  'abelite',
#  'abelmoschus',
#  'abelmosk',
#  'abelonian',
#  'abeltree',
#  'abencerrages',
#  'abenteric',
#  'abepithymia',
#  'aberdeen',
#  'aberdevine',
#  'aberdonian',
#  'aberia',
#  'aberrance',
#  'aberrancy',
#  'aberrant',
#  'aberrate',
#  'aberration',
#  'aberrational',
#  'aberrator',
#  'aberrometer',
#  'aberroscope',
#  'aberuncator',
#  'abet',
#  'abetment',
#  'abettal',
#  'abettor',
#  'abevacuation',
#  'abey',
#  'abeyance',
#  'abeyancy',
#  'abeyant',
#  'abfarad',
#  'abhenry',
#  'abhiseka',
#  'abhominable',
#  'abhor',
#  'abhorrence',
#  'abhorrency',
#  'abhorrent',
#  'abhorrently',
#  'abhorrer',
#  'abhorrible',
#  'abhorring',
#  'abhorson',
#  'abidal',
#  'abidance',
#  'abide',
#  'abider',
#  'abidi',
#  'abiding',
#  'abidingly',
#  'abidingness',
#  'abie',
#  'abies',
#  'abietate',
#  'abietene',
#  'abietic',
#  'abietin',
#  'abietineae',
#  'abietineous',
#  'abietinic',
#  'abiezer',
#  'abigail',
#  'abigail',
#  'abigailship',
#  'abigeat',
#  'abigeus',
#  'abilao',
#  'ability',
#  'abilla',
#  'abilo',
#  'abintestate',
#  'abiogenesis',
#  'abiogenesist',
#  'abiogenetic',
#  'abiogenetical',
#  'abiogenetically',
#  'abiogenist',
#  'abiogenous',
#  'abiogeny',
#  'abiological',
#  'abiologically',
#  'abiology',
#  'abiosis',
#  'abiotic',
#  'abiotrophic',
#  'abiotrophy',
#  'abipon',
#  'abir',
#  'abirritant',
#  'abirritate',
#  'abirritation',
#  'abirritative',
#  'abiston',
#  'abitibi',
#  'abiuret',
#  'abject',
#  'abjectedness',
#  'abjection',
#  'abjective',
#  'abjectly',
#  'abjectness',
#  'abjoint',
#  'abjudge',
#  'abjudicate',
#  'abjudication',
#  'abjunction',
#  'abjunctive',
#  'abjuration',
#  'abjuratory',
#  'abjure',
#  'abjurement',
#  'abjurer',
#  'abkar',
#  'abkari',
#  'abkhas',
#  'abkhasian',
#  'ablach',
#  'ablactate',
#  'ablactation',
#  'ablare',
#  'ablastemic',
#  'ablastous',
#  'ablate',
#  'ablation',
#  'ablatitious',
#  'ablatival',
#  'ablative',
#  'ablator',
#  'ablaut',
#  'ablaze',
#  'able',
#  'ableeze',
#  'ablegate',
#  'ableness',
#  'ablepharia',
#  'ablepharon',
#  'ablepharous',
#  'ablepharus',
#  'ablepsia',
#  'ableptical',
#  'ableptically',
#  'abler',
#  'ablest',
#  'ablewhackets',
#  'ablins',
#  'abloom',
#  'ablow',
#  'ablude',
#  'abluent',
#  'ablush',
#  'ablution',
#  'ablutionary',
#  'abluvion',
#  'ably',
#  'abmho',
#  'abnaki',
#  'abnegate',
#  'abnegation',
#  'abnegative',
#  'abnegator',
#  'abner',
#  'abnerval',
#  'abnet',
#  'abneural',
#  'abnormal',
#  'abnormalism',
#  'abnormalist',
#  'abnormality',
#  'abnormalize',
#  'abnormally',
#  'abnormalness',
#  'abnormity',
#  'abnormous',
#  'abnumerable',
#  'abo',
#  'aboard',
#  'abobra',
#  'abode',
#  'abodement',
#  'abody',
#  'abohm',
#  'aboil',
#  'abolish',
#  'abolisher',
#  'abolishment',
#  'abolition',
#  'abolitionary',
#  'abolitionism',
#  'abolitionist',
#  'abolitionize',
#  'abolla',
#  'aboma',
#  'abomasum',
#  'abomasus',
#  'abominable',
#  'abominableness',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abominator',
#  'abomine',
#  'abongo',
#  'aboon',
#  'aborad',
#  'aboral',
#  'aborally',
#  'abord',
#  'aboriginal',
#  'aboriginality',
#  'aboriginally',
#  'aboriginary',
#  'aborigine',
#  'abort',
#  'aborted',
#  'aborticide',
#  'abortient',
#  'abortifacient',
#  'abortin',
#  'abortion',
#  'abortional',
#  'abortionist',
#  'abortive',
#  'abortively',
#  'abortiveness',
#  'abortus',
#  'abouchement',
#  'abound',
#  'abounder',
#  'abounding',
#  'aboundingly',
#  'about',
#  'abouts',
#  'above',
#  'aboveboard',
#  'abovedeck',
#  'aboveground',
#  'aboveproof',
#  'abovestairs',
#  'abox',
#  'abracadabra',
#  'abrachia',
#  'abradant',
#  'abrade',
#  'abrader',
#  'abraham',
#  'abrahamic',
#  'abrahamidae',
#  'abrahamite',
#  'abrahamitic',
#  'abraid',
#  'abram',
#  'abramis',
#  'abranchial',
#  'abranchialism',
#  'abranchian',
#  'abranchiata',
#  'abranchiate',
#  'abranchious',
#  'abrasax',
#  'abrase',
#  'abrash',
#  'abrasiometer',
#  'abrasion',
#  'abrasive',
#  'abrastol',
#  'abraum',
#  'abraxas',
#  'abreact',
#  'abreaction',
#  'abreast',
#  'abrenounce',
#  'abret',
#  'abrico',
#  'abridge',
#  'abridgeable',
#  'abridged',
#  'abridgedly',
#  'abridger',
#  'abridgment',
#  'abrim',
#  'abrin',
#  'abristle',
#  'abroach',
#  'abroad',
#  'abrocoma',
#  'abrocome',
#  'abrogable',
#  'abrogate',
#  'abrogation',
#  'abrogative',
#  'abrogator',
#  'abroma',
#  'abronia',
#  'abrook',
#  'abrotanum',
#  'abrotine',
#  'abrupt',
#  'abruptedly',
#  'abruption',
#  'abruptly',
#  'abruptness',
#  'abrus',
#  'absalom',
#  'absampere',
#  'absaroka',
#  'absarokite',
#  'abscess',
#  'abscessed',
#  'abscession',
#  'abscessroot',
#  'abscind',
#  'abscise',
#  'abscision',
#  'absciss',
#  'abscissa',
#  'abscissae',
#  'abscisse',
#  'abscission',
#  'absconce',
#  'abscond',
#  'absconded',
#  'abscondedly',
#  'abscondence',
#  'absconder',
#  'absconsa',
#  'abscoulomb',
#  'absence',
#  'absent',
#  'absentation',
#  'absentee',
#  'absenteeism',
#  'absenteeship',
#  'absenter',
#  'absently',
#  'absentment',
#  'absentmindedly',
#  'absentness',
#  'absfarad',
#  'abshenry',
#  'absi',
#  'absinthe',
#  'absinthial',
#  'absinthian',
#  'absinthiate',
#  'absinthic',
#  'absinthin',
#  'absinthine',
#  'absinthism',
#  'absinthismic',
#  'absinthium',
#  'absinthol',
#  'absit',
#  'absmho',
#  'absohm',
#  'absolute',
#  'absolutely',
#  'absoluteness',
#  'absolution',
#  'absolutism',
#  'absolutist',
#  'absolutistic',
#  'absolutistically',
#  'absolutive',
#  'absolutization',
#  'absolutize',
#  'absolutory',
#  'absolvable',
#  'absolvatory',
#  'absolve',
#  'absolvent',
#  'absolver',
#  'absolvitor',
#  'absolvitory',
#  'absonant',
#  'absonous',
#  'absorb',
#  'absorbability',
#  'absorbable',
#  'absorbed',
#  'absorbedly',
#  'absorbedness',
#  'absorbefacient',
#  'absorbency',
#  'absorbent',
#  'absorber',
#  'absorbing',
#  'absorbingly',
#  'absorbition',
#  'absorpt',
#  'absorptance',
#  'absorptiometer',
#  'absorptiometric',
#  'absorption',
#  'absorptive',
#  'absorptively',
#  'absorptiveness',
#  'absorptivity',
#  'absquatulate',
#  'abstain',
#  'abstainer',
#  'abstainment',
#  'abstemious',
#  'abstemiously',
#  'abstemiousness',
#  'abstention',
#  'abstentionist',
#  'abstentious',
#  'absterge',
#  'abstergent',
#  'abstersion',
#  'abstersive',
#  'abstersiveness',
#  'abstinence',
#  'abstinency',
#  'abstinent',
#  'abstinential',
#  'abstinently',
#  'abstract',
#  'abstracted',
#  'abstractedly',
#  'abstractedness',
#  'abstracter',
#  'abstraction',
#  'abstractional',
#  'abstractionism',
#  'abstractionist',
#  'abstractitious',
#  'abstractive',
#  'abstractively',
#  'abstractiveness',
#  'abstractly',
#  'abstractness',
#  'abstractor',
#  'abstrahent',
#  'abstricted',
#  'abstriction',
#  'abstruse',
#  'abstrusely',
#  'abstruseness',
#  'abstrusion',
#  'abstrusity',
#  'absume',
#  'absumption',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'absvolt',
#  'absyrtus',
#  'abterminal',
#  'abthain',
#  'abthainrie',
#  'abthainry',
#  'abthanage',
#  'abu',
#  'abu',
#  'abucco',
#  'abulia',
#  'abulic',
#  'abulomania',
#  'abuna',
#  'abundance',
#  'abundancy',
#  'abundant',
#  'abundantia',
#  'abundantly',
#  'abura',
#  'aburabozu',
#  'aburban',
#  'aburst',
#  'aburton',
#  'abusable',
#  'abuse',
#  'abusedly',
#  'abusee',
#  'abuseful',
#  'abusefully',
#  'abusefulness',
#  'abuser',
#  'abusion',
#  'abusious',
#  'abusive',
#  'abusively',
#  'abusiveness',
#  'abut',
#  'abuta',
#  'abutilon',
#  'abutment',
#  'abuttal',
#  'abutter',
#  'abutting',
#  'abuzz',
#  'abvolt',
#  'abwab',
#  'aby',
#  'abysm',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'abyssal',
#  'abyssinian',
#  'abyssobenthonic',
#  'abyssolith',
#  'abyssopelagic',
#  'acacatechin',
#  'acacatechol',
#  'acacetin',
#  'acacia',
#  'acacian',
#  'acaciin',
#  'acacin',
#  'academe',
#  'academial',
#  'academian',
#  'academic',
#  'academic',
#  'academical',
#  'academically',
#  'academicals',
#  'academician',
#  'academicism',
#  'academism',
#  'academist',
#  'academite',
#  'academization',
#  'academize',
#  'academus',
#  'academy',
#  'acadia',
#  'acadialite',
#  'acadian',
#  'acadie',
#  'acaena',
#  'acajou',
#  'acaleph',
#  'acalepha',
#  'acalephae',
#  'acalephan',
#  'acalephoid',
#  'acalycal',
#  'acalycine',
#  'acalycinous',
#  'acalyculate',
#  'acalypha',
#  'acalypterae',
#  'acalyptrata',
#  'acalyptratae',
#  'acalyptrate',
#  'acamar',
#  'acampsia',
#  'acana',
#  'acanaceous',
#  'acanonical',
#  'acanth',
#  'acantha',
#  'acanthaceae',
#  'acanthaceous',
#  'acanthad',
#  'acantharia',
#  'acanthia',
#  'acanthial',
#  'acanthin',
#  'acanthine',
#  'acanthion',
#  'acanthite',
#  'acanthocarpous',
#  'acanthocephala',
#  'acanthocephalan',
#  'acanthocephali',
#  'acanthocephalous',
#  'acanthocereus',
#  'acanthocladous',
#  'acanthodea',
#  'acanthodean',
#  'acanthodei',
#  'acanthodes',
#  'acanthodian',
#  'acanthodidae',
#  'acanthodii',
#  'acanthodini',
#  'acanthoid',
#  'acantholimon',
#  'acanthological',
#  'acanthology',
#  'acantholysis',
#  'acanthoma',
#  'acanthomeridae',
#  'acanthon',
#  'acanthopanax',
#  'acanthophis',
#  'acanthophorous',
#  'acanthopod',
#  'acanthopodous',
#  'acanthopomatous',
#  'acanthopore',
#  'acanthopteran',
#  'acanthopteri',
#  'acanthopterous',
#  'acanthopterygian',
#  'acanthopterygii',
#  'acanthosis',
#  'acanthous',
#  'acanthuridae',
#  'acanthurus',
#  'acanthus',
#  'acapnia',
#  'acapnial',
#  'acapsular',
#  'acapu',
#  'acapulco',
#  'acara',
#  'acarapis',
#  'acardia',
#  'acardiac',
#  'acari',
#  'acarian',
#  'acariasis',
#  'acaricidal',
#  'acaricide',
#  'acarid',
#  'acarida',
#  'acaridea',
#  'acaridean',
#  'acaridomatium',
#  'acariform',
#  'acarina',
#  'acarine',
#  'acarinosis',
#  'acarocecidium',
#  'acarodermatitis',
#  'acaroid',
#  'acarol',
#  'acarologist',
#  'acarology',
#  'acarophilous',
#  'acarophobia',
#  'acarotoxic',
#  'acarpelous',
#  'acarpous',
#  'acarus',
#  'acastus',
#  'acatalectic',
#  'acatalepsia',
#  'acatalepsy',
#  'acataleptic',
#  'acatallactic',
#  'acatamathesia',
#  'acataphasia',
#  'acataposis',
#  'acatastasia',
#  'acatastatic',
#  'acate',
#  'acategorical',
#  'acatery',
#  'acatharsia',
#  'acatharsy',
#  'acatholic',
#  'acaudal',
#  'acaudate',
#  'acaulescent',
#  'acauline',
#  'acaulose',
#  'acaulous',
#  'acca',
#  'accede',
#  'accedence',
#  'acceder',
#  'accelerable',
#  'accelerando',
#  'accelerant',
#  'accelerate',
#  'accelerated',
#  'acceleratedly',
#  'acceleration',
#  'accelerative',
#  'accelerator',
#  'acceleratory',
#  'accelerograph',
#  'accelerometer',
#  'accend',
#  'accendibility',
#  'accendible',
#  'accension',
#  'accensor',
#  'accent',
#  'accentless',
#  'accentor',
#  'accentuable',
#  'accentual',
#  'accentuality',
#  'accentually',
#  'accentuate',
#  'accentuation',
#  'accentuator',
#  'accentus',
#  'accept',
#  'acceptability',
#  'acceptable',
#  'acceptableness',
#  'acceptably',
#  'acceptance',
#  'acceptancy',
#  'acceptant',
#  'acceptation',
#  'accepted',
#  'acceptedly',
#  'accepter',
#  'acceptilate',
#  'acceptilation',
#  'acception',
#  'acceptive',
#  'acceptor',
#  'acceptress',
#  'accerse',
#  'accersition',
#  'accersitor',
#  'access',
#  'accessarily',
#  'accessariness',
#  'accessary',
#  'accessaryship',
#  'accessibility',
#  'accessible',
#  'accessibly',
#  'accession',
#  'accessional',
#  'accessioner',
#  'accessive',
#  'accessively',
#  'accessless',
#  'accessorial',
#  'accessorily',
#  'accessoriness',
#  'accessorius',
#  'accessory',
#  'accidence',
#  'accidency',
#  'accident',
#  'accidental',
#  'accidentalism',
#  'accidentalist',
#  'accidentality',
#  'accidentally',
#  'accidentalness',
#  'accidented',
#  'accidential',
#  'accidentiality',
#  'accidently',
#  'accidia',
#  'accidie',
#  'accinge',
#  'accipient',
#  'accipiter',
#  'accipitral',
#  'accipitrary',
#  'accipitres',
#  'accipitrine',
#  'accismus',
#  'accite',
#  'acclaim',
#  'acclaimable',
#  'acclaimer',
#  'acclamation',
#  'acclamator',
#  'acclamatory',
#  'acclimatable',
#  'acclimatation',
#  'acclimate',
#  'acclimatement',
#  'acclimation',
#  'acclimatizable',
#  'acclimatization',
#  'acclimatize',
#  'acclimatizer',
#  'acclimature',
#  'acclinal',
#  'acclinate',
#  'acclivitous',
#  'acclivity',
#  'acclivous',
#  'accloy',
#  'accoast',
#  'accoil',
#  'accolade',
#  'accoladed',
#  'accolated',
#  'accolent',
#  'accolle',
#  'accombination',
#  'accommodable',
#  'accommodableness',
#  'accommodate',
#  'accommodately',
#  'accommodateness',
#  'accommodating',
#  'accommodatingly',
#  'accommodation',
#  'accommodational',
#  'accommodative',
#  'accommodativeness',
#  'accommodator',
#  'accompanier',
#  'accompaniment',
#  'accompanimental',
#  'accompanist',
#  'accompany',
#  'accompanyist',
#  'accompletive',
#  'accomplice',
#  'accompliceship',
#  'accomplicity',
#  'accomplish',
#  'accomplishable',
#  'accomplished',
#  'accomplisher',
#  'accomplishment',
#  'accomplisht',
#  'accompt',
#  'accord',
#  'accordable',
#  'accordance',
#  'accordancy',
#  'accordant',
#  ...]

# %%
wordunique = list(set(wordlean))

# %%
wordunique
# Out:
# ['dielectric',
#  'verbid',
#  'photophysical',
#  'condescendingly',
#  'unclustering',
#  'aerobiosis',
#  'assaying',
#  'herborization',
#  'teacherlike',
#  'neuralgy',
#  'jabers',
#  'weathercocky',
#  'enicuridae',
#  'allah',
#  'telephonist',
#  'objectioner',
#  'dollship',
#  'said',
#  'snoove',
#  'counterpetition',
#  'nonpartisanship',
#  'mollichop',
#  'sportily',
#  'fitweed',
#  'splenorrhaphy',
#  'achroous',
#  'knyaz',
#  'unbowsome',
#  'unsisterliness',
#  'deadline',
#  'dilution',
#  'gastraeadae',
#  'lamentatory',
#  'relievedly',
#  'threnode',
#  'lamprophyric',
#  'nymphlike',
#  'passegarde',
#  'regressor',
#  'rubification',
#  'numbles',
#  'harmonichord',
#  'beshlik',
#  'photoheliographic',
#  'poter',
#  'flotage',
#  'siriometer',
#  'antidiffuser',
#  'subcranial',
#  'sloven',
#  'hemogenetic',
#  'tachygraph',
#  'appetibility',
#  'signatory',
#  'mangabeira',
#  'medrick',
#  'slackingly',
#  'universology',
#  'bidigitate',
#  'advocatess',
#  'unapplicably',
#  'glia',
#  'iambelegus',
#  'zeugobranchia',
#  'orphanry',
#  'lyophile',
#  'unexaggerated',
#  'micropathological',
#  'sadic',
#  'servicelessness',
#  'interfector',
#  'charadrine',
#  'nul',
#  'sulfobismuthite',
#  'tippy',
#  'terrifical',
#  'inferential',
#  'sie',
#  'venomer',
#  'cultic',
#  'reappear',
#  'eagre',
#  'upswallow',
#  'roosterless',
#  'undercloth',
#  'pyroarsenious',
#  'punster',
#  'sempiternize',
#  'thaneship',
#  'overpublic',
#  'haunching',
#  'fissirostral',
#  'domiciliar',
#  'unstuffing',
#  'vairy',
#  'doxasticon',
#  'aftercast',
#  'manius',
#  'noncompensating',
#  'otoblennorrhea',
#  'winding',
#  'connumerate',
#  'populousness',
#  'overexpose',
#  'picuris',
#  'iliofemoral',
#  'weapemeoc',
#  'hyperresonant',
#  'hankeringly',
#  'microphthalmus',
#  'chafewax',
#  'catheti',
#  'waiterage',
#  'maricolous',
#  'mobbish',
#  'faunated',
#  'acanthosis',
#  'daffle',
#  'washdish',
#  'blockmaker',
#  'alix',
#  'professorling',
#  'hispaniolate',
#  'grangousier',
#  'detribalize',
#  'preternatural',
#  'unborn',
#  'ichthus',
#  'melanagogal',
#  'tractor',
#  'entrant',
#  'supersensuality',
#  'pericycle',
#  'aecidiospore',
#  'fameuse',
#  'orthostatic',
#  'nifling',
#  'fluviograph',
#  'perennate',
#  'cuproplumbite',
#  'mormonism',
#  'antiricin',
#  'panidrosis',
#  'scaphocephalic',
#  'beholdingness',
#  'subkingdom',
#  'gernitz',
#  'zygomaxillare',
#  'subcultrate',
#  'hydrodamalis',
#  'compliancy',
#  'beater',
#  'wasterfully',
#  'sapium',
#  'outsmile',
#  'supersensualistic',
#  'connation',
#  'enlief',
#  'vint',
#  'supermalate',
#  'diploma',
#  'dolomite',
#  'unelevated',
#  'piperidide',
#  'sera',
#  'lachrymogenic',
#  'parasang',
#  'blastular',
#  'underpraise',
#  'antichurch',
#  'inquirer',
#  'perotic',
#  'statisticize',
#  'monument',
#  'tautonymic',
#  'homoousian',
#  'apicillary',
#  'silicular',
#  'bummler',
#  'butyn',
#  'hydrocardia',
#  'pellian',
#  'dyssynergia',
#  'esthesio',
#  'jocundly',
#  'overprice',
#  'cerniture',
#  'pachyglossous',
#  'earle',
#  'polysepalous',
#  'telluret',
#  'unpartiality',
#  'prehostility',
#  'uninked',
#  'multifoliolate',
#  'misedit',
#  'instrumentist',
#  'macrochemistry',
#  'palaestrian',
#  'kreplech',
#  'enterocoela',
#  'malax',
#  'passionist',
#  'revoluble',
#  'unstandardized',
#  'mazer',
#  'oligotropic',
#  'masturbational',
#  'mislay',
#  'robigalia',
#  'outraught',
#  'taraxacerin',
#  'monapsal',
#  'stogie',
#  'commotion',
#  'gracer',
#  'oculauditory',
#  'phosis',
#  'sheetlet',
#  'unsupped',
#  'bleariness',
#  'afterbreach',
#  'lax',
#  'shylock',
#  'hydroclastic',
#  'bushelwoman',
#  'potgirl',
#  'scouthood',
#  'nephrostomial',
#  'jacobinical',
#  'unrived',
#  'insanitary',
#  'interviewee',
#  'progestin',
#  'monosiphonous',
#  'recentness',
#  'hypochaeris',
#  'bowwow',
#  'gutturally',
#  'hoggin',
#  'paleodendrologist',
#  'gnomologist',
#  'permutational',
#  'rate',
#  'immediately',
#  'heterophemize',
#  'camshachle',
#  'clerking',
#  'hunker',
#  'cumbersome',
#  'exaudi',
#  'teenty',
#  'desmachyme',
#  'prioress',
#  'thamudic',
#  'orthoplastic',
#  'desire',
#  'anabiotic',
#  'prepositive',
#  'costotransverse',
#  'indiscipline',
#  'unsubpoenaed',
#  'levance',
#  'biosystematic',
#  'pyrgom',
#  'honorarium',
#  'admonitrix',
#  'blancmange',
#  'desmepithelium',
#  'reis',
#  'ophionid',
#  'schlauraffenland',
#  'supervention',
#  'tarr',
#  'fruitworm',
#  'baccate',
#  'disconcert',
#  'uppish',
#  'presurprisal',
#  'firesafeness',
#  'reunionist',
#  'superabhor',
#  'restis',
#  'nonfixation',
#  'epitheton',
#  'triarchy',
#  'nutritional',
#  'sakieh',
#  'ectoplasm',
#  'sinistrorse',
#  'japaconitine',
#  'reorder',
#  'isomorphism',
#  'tungusic',
#  'maleinoid',
#  'sacope',
#  'unstilled',
#  'spongeless',
#  'dietarian',
#  'sewen',
#  'conenose',
#  'sextolet',
#  'hernanesell',
#  'villanously',
#  'unrefulgent',
#  'tubulibranchiata',
#  'triedly',
#  'depose',
#  'remiges',
#  'skiver',
#  'washrag',
#  'unannexedness',
#  'dacrydium',
#  'plunge',
#  'cysticarpium',
#  'bully',
#  'intramarginal',
#  'quemely',
#  'cancrizans',
#  'flexuous',
#  'tarahumari',
#  'misculture',
#  'tabu',
#  'heteropycnosis',
#  'unexampled',
#  'caw',
#  'distrouser',
#  'appellative',
#  'cytoclasis',
#  'saros',
#  'loveproof',
#  'downweight',
#  'quizzacious',
#  'sextipara',
#  'anticorn',
#  'doughlike',
#  'sulfarsenite',
#  'unembryonic',
#  'perendination',
#  'overpiteous',
#  'suspensoid',
#  'swadeshism',
#  'herderite',
#  'cynomorphic',
#  'nonrecoverable',
#  'insectiform',
#  'fissidentaceous',
#  'cookout',
#  'poliencephalomyelitis',
#  'teda',
#  'churn',
#  'adversatively',
#  'trinity',
#  'anthracin',
#  'overfreedom',
#  'cassiopeian',
#  'overnigh',
#  'assessably',
#  'archipresbyter',
#  'semirotunda',
#  'matthieu',
#  'thresh',
#  'superbious',
#  'neurology',
#  'boebera',
#  'communicating',
#  'prefecundation',
#  'analysation',
#  'rarity',
#  'elfwife',
#  'youngling',
#  'copsewooded',
#  'venator',
#  'yokeage',
#  'flakelet',
#  'hyperdicrotic',
#  'stromal',
#  'hyposphene',
#  'mongler',
#  'papyrology',
#  'sclerocornea',
#  'architectonica',
#  'galvayning',
#  'somatognostic',
#  'argininephosphoric',
#  'dictyota',
#  'strawstacker',
#  'ruffer',
#  'jokingly',
#  'weismannism',
#  'machinery',
#  'inconnu',
#  'mucin',
#  'viceroy',
#  'connate',
#  'insinuatingly',
#  'overdunged',
#  'cheapside',
#  'phenoloid',
#  'semeia',
#  'goave',
#  'interspecial',
#  'ethicalism',
#  'xanthiuria',
#  'completeness',
#  'traditorship',
#  'overfew',
#  'treponemiasis',
#  'spinster',
#  'triplite',
#  'nonadherence',
#  'hypocritic',
#  'committeewoman',
#  'infieldsman',
#  'pitahauirata',
#  'triose',
#  'allotter',
#  'examinability',
#  'olfactometer',
#  'pleuronectid',
#  'triopidae',
#  'thiodiazole',
#  'tift',
#  'withheld',
#  'omniprevalent',
#  'contraoctave',
#  'saxtie',
#  'sneezeweed',
#  'unperforated',
#  'acroparesthesia',
#  'hydnocarpic',
#  'soddenly',
#  'carvol',
#  'suist',
#  'asperously',
#  'deformedness',
#  'flouter',
#  'mediastinum',
#  'circumradius',
#  'outmalaprop',
#  'silvan',
#  'counterforce',
#  'lurker',
#  'reporteress',
#  'orthopedically',
#  'shotmaker',
#  'smalter',
#  'pseudonavicella',
#  'decorable',
#  'mukti',
#  'orthopoda',
#  'antapocha',
#  'impingement',
#  'papilio',
#  'pneumocele',
#  'pamperer',
#  'pseudoanthorine',
#  'sylvanity',
#  'uncorrigible',
#  'unrural',
#  'woodenness',
#  'unreputable',
#  'overheap',
#  'megalomelia',
#  'cresylic',
#  'harpullia',
#  'postcaecal',
#  'presumptuousness',
#  'reacknowledge',
#  'unbow',
#  'relimitation',
#  'encyclopedically',
#  'urosomitic',
#  'buyides',
#  'hemibasidiales',
#  'outswarm',
#  'landgravate',
#  'conscriptional',
#  'uncontrastable',
#  'improvisatorially',
#  'senilely',
#  'holobenthic',
#  'intrusive',
#  'spousage',
#  'tickleness',
#  'response',
#  'unfoul',
#  'jasey',
#  'sweepdom',
#  'aerophore',
#  'phasm',
#  'prehaustorium',
#  'influencive',
#  'unbetrothed',
#  'hoopwood',
#  'pellucidity',
#  'pluckedness',
#  'restaurant',
#  'soakaway',
#  'qurti',
#  'riddel',
#  'angolar',
#  'imaginant',
#  'porge',
#  'empanel',
#  'coquitlam',
#  'inheritress',
#  'lateromarginal',
#  'porcellanid',
#  'tiresmith',
#  'byronic',
#  'clearance',
#  'dynastid',
#  'gonosphere',
#  'master',
#  'orthograde',
#  'gastrectasia',
#  'pumpkin',
#  'underwage',
#  'shorea',
#  'flagless',
#  'dassy',
#  'monadology',
#  'boxen',
#  'beprank',
#  'sclerochoroiditis',
#  'phiomia',
#  'vesuviate',
#  'nonalkaloidal',
#  'fulgorid',
#  'puddly',
#  'prestrengthen',
#  'subservience',
#  'outdwell',
#  'elytrostenosis',
#  'unorganicalness',
#  'fortuned',
#  'sluddery',
#  'anomalistically',
#  'noncommunicable',
#  'protocanonical',
#  'unsickerly',
#  'comprehensibility',
#  'colobin',
#  'irregenerate',
#  'nonemission',
#  'unshrinkability',
#  'unsworn',
#  'epitoniidae',
#  'telekinetic',
#  'murra',
#  'alkylate',
#  'tautomery',
#  'undisplayable',
#  'dactylozooid',
#  'teleostean',
#  'glorification',
#  'alogically',
#  'educatable',
#  'silicify',
#  'prosthodontia',
#  'uneye',
#  'pontederiaceae',
#  'faintly',
#  'spatting',
#  'unripely',
#  'odium',
#  'autocarpian',
#  'misenforce',
#  'splintery',
#  'archive',
#  'mineralogist',
#  'nobility',
#  'iambically',
#  'oust',
#  'churchwardenship',
#  'growingupness',
#  'labyrinthibranchii',
#  'genty',
#  'fishling',
#  'nonselfregarding',
#  'wottest',
#  'strigine',
#  'paragastrular',
#  'protodont',
#  'malplaced',
#  'quantitively',
#  'tonnishly',
#  'incompetentness',
#  'poculiform',
#  'enamourment',
#  'salivous',
#  'masser',
#  'oatmeal',
#  'lexiphanicism',
#  'unredeeming',
#  'crotched',
#  'metoposcopical',
#  'bronchiectasis',
#  'dalibarda',
#  'robe',
#  'unlineal',
#  'radicand',
#  'congressionalist',
#  'norwest',
#  'boweryish',
#  'untwirling',
#  'grubstaker',
#  'unlust',
#  'chinantecs',
#  'undesigningly',
#  'cardophagus',
#  'heptagon',
#  'preoccurrence',
#  'yapman',
#  'gamely',
#  'unorthodox',
#  'oenanthol',
#  'banteng',
#  'broth',
#  'phano',
#  'intemperament',
#  'recallment',
#  'unbraid',
#  'consumptive',
#  'bolt',
#  'aftershine',
#  'morne',
#  'symbiogenetically',
#  'overoffend',
#  'wayworn',
#  'unrobe',
#  'nonconsumption',
#  'lommock',
#  'calculus',
#  'roundly',
#  'spearmint',
#  'leafstalk',
#  'microscopial',
#  'uratemia',
#  'vedantist',
#  'gastroenteric',
#  'substituting',
#  'haematobranchiate',
#  'wisket',
#  'ranger',
#  'goethian',
#  'minometer',
#  'presign',
#  'underboom',
#  'epizoicide',
#  'adam',
#  'piddle',
#  'faintheart',
#  'infiniteness',
#  'slenderly',
#  'viatometer',
#  'unfistulous',
#  'phot',
#  'chalcone',
#  'platyrhini',
#  'carpetmonger',
#  'colletside',
#  'desexualize',
#  'cubicontravariant',
#  'perissologic',
#  'unpeace',
#  'emersonian',
#  'interequinoctial',
#  'concaver',
#  'hortulan',
#  'mediatingly',
#  'schute',
#  'sillandar',
#  'unobtrusively',
#  'isohesperidin',
#  'retranslation',
#  'orlewise',
#  'tenterer',
#  'stingy',
#  'overmagnify',
#  'epiphenomenon',
#  'subhall',
#  'trichodontidae',
#  'propargylic',
#  'polymyoid',
#  'cryptographic',
#  'foppishness',
#  'premycotic',
#  'frantic',
#  'bancal',
#  'memorialist',
#  'panduriform',
#  'refugee',
#  'circumvolution',
#  'thortveitite',
#  'kala',
#  'recto',
#  'decumbence',
#  'diabrotica',
#  'drusedom',
#  'thaumatropical',
#  'atechnical',
#  'unconstitutionally',
#  'deathsman',
#  'fisting',
#  'spearfish',
#  'elod',
#  'germlike',
#  'alphonist',
#  'beshame',
#  'coccidian',
#  'samshu',
#  'digenous',
#  'prelatish',
#  'outfawn',
#  'fumbling',
#  'betulaceous',
#  'bellmaking',
#  'ovomucoid',
#  'arcual',
#  'pharmacologia',
#  'proterandry',
#  'vesiculotomy',
#  'panophthalmia',
#  'bicyclist',
#  'phoo',
#  'seleucidic',
#  'hippiatry',
#  'unclimaxed',
#  'panoptic',
#  'wrote',
#  'dongolese',
#  'epididymovasostomy',
#  'noncounty',
#  'tetraceratous',
#  'sulphethylate',
#  'obole',
#  'unfoliaged',
#  'doctorate',
#  'indianeer',
#  'nonsmoking',
#  'unbuoyant',
#  'obtusely',
#  'overchurch',
#  'agglutinable',
#  'unimbowed',
#  'pestify',
#  'unshavenly',
#  'exegete',
#  'amphiboly',
#  'aperture',
#  'soally',
#  'forride',
#  'antistadholder',
#  'pasul',
#  'tussock',
#  'decrepitly',
#  'subecho',
#  'enrol',
#  'retepora',
#  'ilkane',
#  'lalang',
#  'postpyloric',
#  'upstem',
#  'unshockable',
#  'dadoxylon',
#  'metonymic',
#  'raft',
#  'jacobsite',
#  'uningenuousness',
#  'targumical',
#  'cacoepistic',
#  'fink',
#  'taxonomically',
#  'vocalise',
#  'shook',
#  'perineuritis',
#  'uncouthly',
#  'allotheria',
#  'metaplumbate',
#  'charivari',
#  'knocking',
#  'sternways',
#  'apocope',
#  'unmysteriously',
#  'fadridden',
#  'muricidae',
#  'unproven',
#  'violature',
#  'inarticulacy',
#  'atrabiliousness',
#  'hoopla',
#  'nonsingular',
#  'unbung',
#  'paramitome',
#  'rethink',
#  'autodepolymerization',
#  'overdiversification',
#  'prevalid',
#  'purpurogenous',
#  'alushtite',
#  'syllabatim',
#  'disjunctor',
#  'wasty',
#  'holometer',
#  'loaden',
#  'featherbedding',
#  'fruitage',
#  'scatophagidae',
#  'transplendency',
#  'opticociliary',
#  'running',
#  'diabetic',
#  'adamic',
#  'froggery',
#  'phycodromidae',
#  'phrenicectomy',
#  'imaginist',
#  'katik',
#  'tatler',
#  'soundage',
#  'radiobroadcast',
#  'gradometer',
#  'transcriptively',
#  'cobaltocyanic',
#  'antiputrefactive',
#  'pardoning',
#  'catalyzer',
#  'monepiscopacy',
#  'overkeenness',
#  'summerly',
#  'thuribulum',
#  'onymy',
#  'procurable',
#  'betoya',
#  'monolinguist',
#  'androtauric',
#  'invectively',
#  'adamically',
#  'gifted',
#  'pointed',
#  'pinfeather',
#  'unscornful',
#  'larcenously',
#  'improviso',
#  'allotropize',
#  'fossilation',
#  'plomb',
#  'animatingly',
#  'catacaustic',
#  'culeus',
#  'heterostrophous',
#  'conveyal',
#  'afrikaans',
#  'forfeit',
#  'boethusian',
#  'precocity',
#  'hodmandod',
#  'metalization',
#  'praxinoscope',
#  'amphitheatral',
#  'beldam',
#  'prevacation',
#  'unfutile',
#  'xylem',
#  'assmanship',
#  'prereturn',
#  'venereologist',
#  'coherence',
#  'warrand',
#  'prejudicator',
#  'sultanlike',
#  'ananaples',
#  'unshady',
#  'noncommencement',
#  'japonically',
#  'gustativeness',
#  'intaglio',
#  'stupidish',
#  'ascendency',
#  'redissolvable',
#  'laryngoparalysis',
#  'rudimentary',
#  'sacrococcygeus',
#  'photogyric',
#  'monotelephonic',
#  'prosoplasia',
#  'sensibility',
#  'diact',
#  'polybasite',
#  'surmount',
#  'tosily',
#  'kanga',
#  'erect',
#  'maltha',
#  'marrubium',
#  'semiruin',
#  'tomboyishly',
#  'unfrightful',
#  'unnymphlike',
#  'motographic',
#  'ciboney',
#  'wranglingly',
#  'meditullium',
#  'predisagree',
#  'porphyra',
#  'tartane',
#  'chott',
#  'althaea',
#  'noncollegiate',
#  'ytterbium',
#  'bibionidae',
#  'darci',
#  'antepectoral',
#  'kaiwi',
#  'quitclaim',
#  'indemonstrably',
#  'ranivorous',
#  'piacularness',
#  'superindulgent',
#  'transversalis',
#  'ceratostomataceae',
#  'predefect',
#  'neoplatonician',
#  'backing',
#  'pim',
#  'homalosternal',
#  'oleomargarine',
#  'interminant',
#  'qualityship',
#  'precipitantly',
#  'unrespected',
#  'recaptor',
#  'bemitered',
#  'mesenteriolum',
#  'brigatry',
#  'bail',
#  'majagga',
#  'tetrapneumonous',
#  'tronador',
#  'plagosity',
#  'whereupon',
#  'adenostoma',
#  'actually',
#  'sonderclass',
#  'versatilely',
#  'knifesmith',
#  'prezygomatic',
#  'undiplomatic',
#  'tungstite',
#  'terebratula',
#  'barbulate',
#  'unspitted',
#  'pluricentral',
#  'refoot',
#  'vacuumize',
#  'amarantus',
#  'toneme',
#  'thilk',
#  'heavenize',
#  'graphometrical',
#  'despairing',
#  'mitigator',
#  'terramara',
#  'suddenness',
#  'retrogressively',
#  'ironworker',
#  'willyer',
#  'belayer',
#  'immovably',
#  'natter',
#  'inobediently',
#  'weightily',
#  'disastrousness',
#  'yttria',
#  'weinbergerite',
#  'photologic',
#  'unpostmarked',
#  'nectareously',
#  'resort',
#  'emboldener',
#  'laurdalite',
#  'regulus',
#  'callable',
#  'dermatoplasty',
#  'pincer',
#  'worricow',
#  'nonconversational',
#  'micronesian',
#  'synoecize',
#  'discolith',
#  'nonimmateriality',
#  'abstemious',
#  'mimeo',
#  'fo',
#  'monohybrid',
#  'pentaspermous',
#  'bookishly',
#  'woodrock',
#  ...]

# %%
wordunique = list(set(wordlean))

# %%
wordunique
# Out:
# ['dielectric',
#  'verbid',
#  'photophysical',
#  'condescendingly',
#  'unclustering',
#  'aerobiosis',
#  'assaying',
#  'herborization',
#  'teacherlike',
#  'neuralgy',
#  'jabers',
#  'weathercocky',
#  'enicuridae',
#  'allah',
#  'telephonist',
#  'objectioner',
#  'dollship',
#  'said',
#  'snoove',
#  'counterpetition',
#  'nonpartisanship',
#  'mollichop',
#  'sportily',
#  'fitweed',
#  'splenorrhaphy',
#  'achroous',
#  'knyaz',
#  'unbowsome',
#  'unsisterliness',
#  'deadline',
#  'dilution',
#  'gastraeadae',
#  'lamentatory',
#  'relievedly',
#  'threnode',
#  'lamprophyric',
#  'nymphlike',
#  'passegarde',
#  'regressor',
#  'rubification',
#  'numbles',
#  'harmonichord',
#  'beshlik',
#  'photoheliographic',
#  'poter',
#  'flotage',
#  'siriometer',
#  'antidiffuser',
#  'subcranial',
#  'sloven',
#  'hemogenetic',
#  'tachygraph',
#  'appetibility',
#  'signatory',
#  'mangabeira',
#  'medrick',
#  'slackingly',
#  'universology',
#  'bidigitate',
#  'advocatess',
#  'unapplicably',
#  'glia',
#  'iambelegus',
#  'zeugobranchia',
#  'orphanry',
#  'lyophile',
#  'unexaggerated',
#  'micropathological',
#  'sadic',
#  'servicelessness',
#  'interfector',
#  'charadrine',
#  'nul',
#  'sulfobismuthite',
#  'tippy',
#  'terrifical',
#  'inferential',
#  'sie',
#  'venomer',
#  'cultic',
#  'reappear',
#  'eagre',
#  'upswallow',
#  'roosterless',
#  'undercloth',
#  'pyroarsenious',
#  'punster',
#  'sempiternize',
#  'thaneship',
#  'overpublic',
#  'haunching',
#  'fissirostral',
#  'domiciliar',
#  'unstuffing',
#  'vairy',
#  'doxasticon',
#  'aftercast',
#  'manius',
#  'noncompensating',
#  'otoblennorrhea',
#  'winding',
#  'connumerate',
#  'populousness',
#  'overexpose',
#  'picuris',
#  'iliofemoral',
#  'weapemeoc',
#  'hyperresonant',
#  'hankeringly',
#  'microphthalmus',
#  'chafewax',
#  'catheti',
#  'waiterage',
#  'maricolous',
#  'mobbish',
#  'faunated',
#  'acanthosis',
#  'daffle',
#  'washdish',
#  'blockmaker',
#  'alix',
#  'professorling',
#  'hispaniolate',
#  'grangousier',
#  'detribalize',
#  'preternatural',
#  'unborn',
#  'ichthus',
#  'melanagogal',
#  'tractor',
#  'entrant',
#  'supersensuality',
#  'pericycle',
#  'aecidiospore',
#  'fameuse',
#  'orthostatic',
#  'nifling',
#  'fluviograph',
#  'perennate',
#  'cuproplumbite',
#  'mormonism',
#  'antiricin',
#  'panidrosis',
#  'scaphocephalic',
#  'beholdingness',
#  'subkingdom',
#  'gernitz',
#  'zygomaxillare',
#  'subcultrate',
#  'hydrodamalis',
#  'compliancy',
#  'beater',
#  'wasterfully',
#  'sapium',
#  'outsmile',
#  'supersensualistic',
#  'connation',
#  'enlief',
#  'vint',
#  'supermalate',
#  'diploma',
#  'dolomite',
#  'unelevated',
#  'piperidide',
#  'sera',
#  'lachrymogenic',
#  'parasang',
#  'blastular',
#  'underpraise',
#  'antichurch',
#  'inquirer',
#  'perotic',
#  'statisticize',
#  'monument',
#  'tautonymic',
#  'homoousian',
#  'apicillary',
#  'silicular',
#  'bummler',
#  'butyn',
#  'hydrocardia',
#  'pellian',
#  'dyssynergia',
#  'esthesio',
#  'jocundly',
#  'overprice',
#  'cerniture',
#  'pachyglossous',
#  'earle',
#  'polysepalous',
#  'telluret',
#  'unpartiality',
#  'prehostility',
#  'uninked',
#  'multifoliolate',
#  'misedit',
#  'instrumentist',
#  'macrochemistry',
#  'palaestrian',
#  'kreplech',
#  'enterocoela',
#  'malax',
#  'passionist',
#  'revoluble',
#  'unstandardized',
#  'mazer',
#  'oligotropic',
#  'masturbational',
#  'mislay',
#  'robigalia',
#  'outraught',
#  'taraxacerin',
#  'monapsal',
#  'stogie',
#  'commotion',
#  'gracer',
#  'oculauditory',
#  'phosis',
#  'sheetlet',
#  'unsupped',
#  'bleariness',
#  'afterbreach',
#  'lax',
#  'shylock',
#  'hydroclastic',
#  'bushelwoman',
#  'potgirl',
#  'scouthood',
#  'nephrostomial',
#  'jacobinical',
#  'unrived',
#  'insanitary',
#  'interviewee',
#  'progestin',
#  'monosiphonous',
#  'recentness',
#  'hypochaeris',
#  'bowwow',
#  'gutturally',
#  'hoggin',
#  'paleodendrologist',
#  'gnomologist',
#  'permutational',
#  'rate',
#  'immediately',
#  'heterophemize',
#  'camshachle',
#  'clerking',
#  'hunker',
#  'cumbersome',
#  'exaudi',
#  'teenty',
#  'desmachyme',
#  'prioress',
#  'thamudic',
#  'orthoplastic',
#  'desire',
#  'anabiotic',
#  'prepositive',
#  'costotransverse',
#  'indiscipline',
#  'unsubpoenaed',
#  'levance',
#  'biosystematic',
#  'pyrgom',
#  'honorarium',
#  'admonitrix',
#  'blancmange',
#  'desmepithelium',
#  'reis',
#  'ophionid',
#  'schlauraffenland',
#  'supervention',
#  'tarr',
#  'fruitworm',
#  'baccate',
#  'disconcert',
#  'uppish',
#  'presurprisal',
#  'firesafeness',
#  'reunionist',
#  'superabhor',
#  'restis',
#  'nonfixation',
#  'epitheton',
#  'triarchy',
#  'nutritional',
#  'sakieh',
#  'ectoplasm',
#  'sinistrorse',
#  'japaconitine',
#  'reorder',
#  'isomorphism',
#  'tungusic',
#  'maleinoid',
#  'sacope',
#  'unstilled',
#  'spongeless',
#  'dietarian',
#  'sewen',
#  'conenose',
#  'sextolet',
#  'hernanesell',
#  'villanously',
#  'unrefulgent',
#  'tubulibranchiata',
#  'triedly',
#  'depose',
#  'remiges',
#  'skiver',
#  'washrag',
#  'unannexedness',
#  'dacrydium',
#  'plunge',
#  'cysticarpium',
#  'bully',
#  'intramarginal',
#  'quemely',
#  'cancrizans',
#  'flexuous',
#  'tarahumari',
#  'misculture',
#  'tabu',
#  'heteropycnosis',
#  'unexampled',
#  'caw',
#  'distrouser',
#  'appellative',
#  'cytoclasis',
#  'saros',
#  'loveproof',
#  'downweight',
#  'quizzacious',
#  'sextipara',
#  'anticorn',
#  'doughlike',
#  'sulfarsenite',
#  'unembryonic',
#  'perendination',
#  'overpiteous',
#  'suspensoid',
#  'swadeshism',
#  'herderite',
#  'cynomorphic',
#  'nonrecoverable',
#  'insectiform',
#  'fissidentaceous',
#  'cookout',
#  'poliencephalomyelitis',
#  'teda',
#  'churn',
#  'adversatively',
#  'trinity',
#  'anthracin',
#  'overfreedom',
#  'cassiopeian',
#  'overnigh',
#  'assessably',
#  'archipresbyter',
#  'semirotunda',
#  'matthieu',
#  'thresh',
#  'superbious',
#  'neurology',
#  'boebera',
#  'communicating',
#  'prefecundation',
#  'analysation',
#  'rarity',
#  'elfwife',
#  'youngling',
#  'copsewooded',
#  'venator',
#  'yokeage',
#  'flakelet',
#  'hyperdicrotic',
#  'stromal',
#  'hyposphene',
#  'mongler',
#  'papyrology',
#  'sclerocornea',
#  'architectonica',
#  'galvayning',
#  'somatognostic',
#  'argininephosphoric',
#  'dictyota',
#  'strawstacker',
#  'ruffer',
#  'jokingly',
#  'weismannism',
#  'machinery',
#  'inconnu',
#  'mucin',
#  'viceroy',
#  'connate',
#  'insinuatingly',
#  'overdunged',
#  'cheapside',
#  'phenoloid',
#  'semeia',
#  'goave',
#  'interspecial',
#  'ethicalism',
#  'xanthiuria',
#  'completeness',
#  'traditorship',
#  'overfew',
#  'treponemiasis',
#  'spinster',
#  'triplite',
#  'nonadherence',
#  'hypocritic',
#  'committeewoman',
#  'infieldsman',
#  'pitahauirata',
#  'triose',
#  'allotter',
#  'examinability',
#  'olfactometer',
#  'pleuronectid',
#  'triopidae',
#  'thiodiazole',
#  'tift',
#  'withheld',
#  'omniprevalent',
#  'contraoctave',
#  'saxtie',
#  'sneezeweed',
#  'unperforated',
#  'acroparesthesia',
#  'hydnocarpic',
#  'soddenly',
#  'carvol',
#  'suist',
#  'asperously',
#  'deformedness',
#  'flouter',
#  'mediastinum',
#  'circumradius',
#  'outmalaprop',
#  'silvan',
#  'counterforce',
#  'lurker',
#  'reporteress',
#  'orthopedically',
#  'shotmaker',
#  'smalter',
#  'pseudonavicella',
#  'decorable',
#  'mukti',
#  'orthopoda',
#  'antapocha',
#  'impingement',
#  'papilio',
#  'pneumocele',
#  'pamperer',
#  'pseudoanthorine',
#  'sylvanity',
#  'uncorrigible',
#  'unrural',
#  'woodenness',
#  'unreputable',
#  'overheap',
#  'megalomelia',
#  'cresylic',
#  'harpullia',
#  'postcaecal',
#  'presumptuousness',
#  'reacknowledge',
#  'unbow',
#  'relimitation',
#  'encyclopedically',
#  'urosomitic',
#  'buyides',
#  'hemibasidiales',
#  'outswarm',
#  'landgravate',
#  'conscriptional',
#  'uncontrastable',
#  'improvisatorially',
#  'senilely',
#  'holobenthic',
#  'intrusive',
#  'spousage',
#  'tickleness',
#  'response',
#  'unfoul',
#  'jasey',
#  'sweepdom',
#  'aerophore',
#  'phasm',
#  'prehaustorium',
#  'influencive',
#  'unbetrothed',
#  'hoopwood',
#  'pellucidity',
#  'pluckedness',
#  'restaurant',
#  'soakaway',
#  'qurti',
#  'riddel',
#  'angolar',
#  'imaginant',
#  'porge',
#  'empanel',
#  'coquitlam',
#  'inheritress',
#  'lateromarginal',
#  'porcellanid',
#  'tiresmith',
#  'byronic',
#  'clearance',
#  'dynastid',
#  'gonosphere',
#  'master',
#  'orthograde',
#  'gastrectasia',
#  'pumpkin',
#  'underwage',
#  'shorea',
#  'flagless',
#  'dassy',
#  'monadology',
#  'boxen',
#  'beprank',
#  'sclerochoroiditis',
#  'phiomia',
#  'vesuviate',
#  'nonalkaloidal',
#  'fulgorid',
#  'puddly',
#  'prestrengthen',
#  'subservience',
#  'outdwell',
#  'elytrostenosis',
#  'unorganicalness',
#  'fortuned',
#  'sluddery',
#  'anomalistically',
#  'noncommunicable',
#  'protocanonical',
#  'unsickerly',
#  'comprehensibility',
#  'colobin',
#  'irregenerate',
#  'nonemission',
#  'unshrinkability',
#  'unsworn',
#  'epitoniidae',
#  'telekinetic',
#  'murra',
#  'alkylate',
#  'tautomery',
#  'undisplayable',
#  'dactylozooid',
#  'teleostean',
#  'glorification',
#  'alogically',
#  'educatable',
#  'silicify',
#  'prosthodontia',
#  'uneye',
#  'pontederiaceae',
#  'faintly',
#  'spatting',
#  'unripely',
#  'odium',
#  'autocarpian',
#  'misenforce',
#  'splintery',
#  'archive',
#  'mineralogist',
#  'nobility',
#  'iambically',
#  'oust',
#  'churchwardenship',
#  'growingupness',
#  'labyrinthibranchii',
#  'genty',
#  'fishling',
#  'nonselfregarding',
#  'wottest',
#  'strigine',
#  'paragastrular',
#  'protodont',
#  'malplaced',
#  'quantitively',
#  'tonnishly',
#  'incompetentness',
#  'poculiform',
#  'enamourment',
#  'salivous',
#  'masser',
#  'oatmeal',
#  'lexiphanicism',
#  'unredeeming',
#  'crotched',
#  'metoposcopical',
#  'bronchiectasis',
#  'dalibarda',
#  'robe',
#  'unlineal',
#  'radicand',
#  'congressionalist',
#  'norwest',
#  'boweryish',
#  'untwirling',
#  'grubstaker',
#  'unlust',
#  'chinantecs',
#  'undesigningly',
#  'cardophagus',
#  'heptagon',
#  'preoccurrence',
#  'yapman',
#  'gamely',
#  'unorthodox',
#  'oenanthol',
#  'banteng',
#  'broth',
#  'phano',
#  'intemperament',
#  'recallment',
#  'unbraid',
#  'consumptive',
#  'bolt',
#  'aftershine',
#  'morne',
#  'symbiogenetically',
#  'overoffend',
#  'wayworn',
#  'unrobe',
#  'nonconsumption',
#  'lommock',
#  'calculus',
#  'roundly',
#  'spearmint',
#  'leafstalk',
#  'microscopial',
#  'uratemia',
#  'vedantist',
#  'gastroenteric',
#  'substituting',
#  'haematobranchiate',
#  'wisket',
#  'ranger',
#  'goethian',
#  'minometer',
#  'presign',
#  'underboom',
#  'epizoicide',
#  'adam',
#  'piddle',
#  'faintheart',
#  'infiniteness',
#  'slenderly',
#  'viatometer',
#  'unfistulous',
#  'phot',
#  'chalcone',
#  'platyrhini',
#  'carpetmonger',
#  'colletside',
#  'desexualize',
#  'cubicontravariant',
#  'perissologic',
#  'unpeace',
#  'emersonian',
#  'interequinoctial',
#  'concaver',
#  'hortulan',
#  'mediatingly',
#  'schute',
#  'sillandar',
#  'unobtrusively',
#  'isohesperidin',
#  'retranslation',
#  'orlewise',
#  'tenterer',
#  'stingy',
#  'overmagnify',
#  'epiphenomenon',
#  'subhall',
#  'trichodontidae',
#  'propargylic',
#  'polymyoid',
#  'cryptographic',
#  'foppishness',
#  'premycotic',
#  'frantic',
#  'bancal',
#  'memorialist',
#  'panduriform',
#  'refugee',
#  'circumvolution',
#  'thortveitite',
#  'kala',
#  'recto',
#  'decumbence',
#  'diabrotica',
#  'drusedom',
#  'thaumatropical',
#  'atechnical',
#  'unconstitutionally',
#  'deathsman',
#  'fisting',
#  'spearfish',
#  'elod',
#  'germlike',
#  'alphonist',
#  'beshame',
#  'coccidian',
#  'samshu',
#  'digenous',
#  'prelatish',
#  'outfawn',
#  'fumbling',
#  'betulaceous',
#  'bellmaking',
#  'ovomucoid',
#  'arcual',
#  'pharmacologia',
#  'proterandry',
#  'vesiculotomy',
#  'panophthalmia',
#  'bicyclist',
#  'phoo',
#  'seleucidic',
#  'hippiatry',
#  'unclimaxed',
#  'panoptic',
#  'wrote',
#  'dongolese',
#  'epididymovasostomy',
#  'noncounty',
#  'tetraceratous',
#  'sulphethylate',
#  'obole',
#  'unfoliaged',
#  'doctorate',
#  'indianeer',
#  'nonsmoking',
#  'unbuoyant',
#  'obtusely',
#  'overchurch',
#  'agglutinable',
#  'unimbowed',
#  'pestify',
#  'unshavenly',
#  'exegete',
#  'amphiboly',
#  'aperture',
#  'soally',
#  'forride',
#  'antistadholder',
#  'pasul',
#  'tussock',
#  'decrepitly',
#  'subecho',
#  'enrol',
#  'retepora',
#  'ilkane',
#  'lalang',
#  'postpyloric',
#  'upstem',
#  'unshockable',
#  'dadoxylon',
#  'metonymic',
#  'raft',
#  'jacobsite',
#  'uningenuousness',
#  'targumical',
#  'cacoepistic',
#  'fink',
#  'taxonomically',
#  'vocalise',
#  'shook',
#  'perineuritis',
#  'uncouthly',
#  'allotheria',
#  'metaplumbate',
#  'charivari',
#  'knocking',
#  'sternways',
#  'apocope',
#  'unmysteriously',
#  'fadridden',
#  'muricidae',
#  'unproven',
#  'violature',
#  'inarticulacy',
#  'atrabiliousness',
#  'hoopla',
#  'nonsingular',
#  'unbung',
#  'paramitome',
#  'rethink',
#  'autodepolymerization',
#  'overdiversification',
#  'prevalid',
#  'purpurogenous',
#  'alushtite',
#  'syllabatim',
#  'disjunctor',
#  'wasty',
#  'holometer',
#  'loaden',
#  'featherbedding',
#  'fruitage',
#  'scatophagidae',
#  'transplendency',
#  'opticociliary',
#  'running',
#  'diabetic',
#  'adamic',
#  'froggery',
#  'phycodromidae',
#  'phrenicectomy',
#  'imaginist',
#  'katik',
#  'tatler',
#  'soundage',
#  'radiobroadcast',
#  'gradometer',
#  'transcriptively',
#  'cobaltocyanic',
#  'antiputrefactive',
#  'pardoning',
#  'catalyzer',
#  'monepiscopacy',
#  'overkeenness',
#  'summerly',
#  'thuribulum',
#  'onymy',
#  'procurable',
#  'betoya',
#  'monolinguist',
#  'androtauric',
#  'invectively',
#  'adamically',
#  'gifted',
#  'pointed',
#  'pinfeather',
#  'unscornful',
#  'larcenously',
#  'improviso',
#  'allotropize',
#  'fossilation',
#  'plomb',
#  'animatingly',
#  'catacaustic',
#  'culeus',
#  'heterostrophous',
#  'conveyal',
#  'afrikaans',
#  'forfeit',
#  'boethusian',
#  'precocity',
#  'hodmandod',
#  'metalization',
#  'praxinoscope',
#  'amphitheatral',
#  'beldam',
#  'prevacation',
#  'unfutile',
#  'xylem',
#  'assmanship',
#  'prereturn',
#  'venereologist',
#  'coherence',
#  'warrand',
#  'prejudicator',
#  'sultanlike',
#  'ananaples',
#  'unshady',
#  'noncommencement',
#  'japonically',
#  'gustativeness',
#  'intaglio',
#  'stupidish',
#  'ascendency',
#  'redissolvable',
#  'laryngoparalysis',
#  'rudimentary',
#  'sacrococcygeus',
#  'photogyric',
#  'monotelephonic',
#  'prosoplasia',
#  'sensibility',
#  'diact',
#  'polybasite',
#  'surmount',
#  'tosily',
#  'kanga',
#  'erect',
#  'maltha',
#  'marrubium',
#  'semiruin',
#  'tomboyishly',
#  'unfrightful',
#  'unnymphlike',
#  'motographic',
#  'ciboney',
#  'wranglingly',
#  'meditullium',
#  'predisagree',
#  'porphyra',
#  'tartane',
#  'chott',
#  'althaea',
#  'noncollegiate',
#  'ytterbium',
#  'bibionidae',
#  'darci',
#  'antepectoral',
#  'kaiwi',
#  'quitclaim',
#  'indemonstrably',
#  'ranivorous',
#  'piacularness',
#  'superindulgent',
#  'transversalis',
#  'ceratostomataceae',
#  'predefect',
#  'neoplatonician',
#  'backing',
#  'pim',
#  'homalosternal',
#  'oleomargarine',
#  'interminant',
#  'qualityship',
#  'precipitantly',
#  'unrespected',
#  'recaptor',
#  'bemitered',
#  'mesenteriolum',
#  'brigatry',
#  'bail',
#  'majagga',
#  'tetrapneumonous',
#  'tronador',
#  'plagosity',
#  'whereupon',
#  'adenostoma',
#  'actually',
#  'sonderclass',
#  'versatilely',
#  'knifesmith',
#  'prezygomatic',
#  'undiplomatic',
#  'tungstite',
#  'terebratula',
#  'barbulate',
#  'unspitted',
#  'pluricentral',
#  'refoot',
#  'vacuumize',
#  'amarantus',
#  'toneme',
#  'thilk',
#  'heavenize',
#  'graphometrical',
#  'despairing',
#  'mitigator',
#  'terramara',
#  'suddenness',
#  'retrogressively',
#  'ironworker',
#  'willyer',
#  'belayer',
#  'immovably',
#  'natter',
#  'inobediently',
#  'weightily',
#  'disastrousness',
#  'yttria',
#  'weinbergerite',
#  'photologic',
#  'unpostmarked',
#  'nectareously',
#  'resort',
#  'emboldener',
#  'laurdalite',
#  'regulus',
#  'callable',
#  'dermatoplasty',
#  'pincer',
#  'worricow',
#  'nonconversational',
#  'micronesian',
#  'synoecize',
#  'discolith',
#  'nonimmateriality',
#  'abstemious',
#  'mimeo',
#  'fo',
#  'monohybrid',
#  'pentaspermous',
#  'bookishly',
#  'woodrock',
#  ...]

# %%
wordunique.sort()

# %%
wordunique
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
#  'abashedness',
#  'abashless',
#  'abashlessly',
#  'abashment',
#  'abasia',
#  'abasic',
#  'abask',
#  'abassin',
#  'abastardize',
#  'abatable',
#  'abate',
#  'abatement',
#  'abater',
#  'abatis',
#  'abatised',
#  'abaton',
#  'abator',
#  'abattoir',
#  'abatua',
#  'abature',
#  'abave',
#  'abaxial',
#  'abaxile',
#  'abaze',
#  'abb',
#  'abba',
#  'abbacomes',
#  'abbacy',
#  'abbadide',
#  'abbas',
#  'abbasi',
#  'abbassi',
#  'abbasside',
#  'abbatial',
#  'abbatical',
#  'abbess',
#  'abbey',
#  'abbeystede',
#  'abbie',
#  'abbot',
#  'abbotcy',
#  'abbotnullius',
#  'abbotship',
#  'abbreviate',
#  'abbreviately',
#  'abbreviation',
#  'abbreviator',
#  'abbreviatory',
#  'abbreviature',
#  'abby',
#  'abcoulomb',
#  'abdal',
#  'abdat',
#  'abderian',
#  'abderite',
#  'abdest',
#  'abdicable',
#  'abdicant',
#  'abdicate',
#  'abdication',
#  'abdicative',
#  'abdicator',
#  'abdiel',
#  'abditive',
#  'abditory',
#  'abdomen',
#  'abdominal',
#  'abdominales',
#  'abdominalian',
#  'abdominally',
#  'abdominoanterior',
#  'abdominocardiac',
#  'abdominocentesis',
#  'abdominocystic',
#  'abdominogenital',
#  'abdominohysterectomy',
#  'abdominohysterotomy',
#  'abdominoposterior',
#  'abdominoscope',
#  'abdominoscopy',
#  'abdominothoracic',
#  'abdominous',
#  'abdominovaginal',
#  'abdominovesical',
#  'abduce',
#  'abducens',
#  'abducent',
#  'abduct',
#  'abduction',
#  'abductor',
#  'abe',
#  'abeam',
#  'abear',
#  'abearance',
#  'abecedarian',
#  'abecedarium',
#  'abecedary',
#  'abed',
#  'abeigh',
#  'abel',
#  'abele',
#  'abelia',
#  'abelian',
#  'abelicea',
#  'abelite',
#  'abelmoschus',
#  'abelmosk',
#  'abelonian',
#  'abeltree',
#  'abencerrages',
#  'abenteric',
#  'abepithymia',
#  'aberdeen',
#  'aberdevine',
#  'aberdonian',
#  'aberia',
#  'aberrance',
#  'aberrancy',
#  'aberrant',
#  'aberrate',
#  'aberration',
#  'aberrational',
#  'aberrator',
#  'aberrometer',
#  'aberroscope',
#  'aberuncator',
#  'abet',
#  'abetment',
#  'abettal',
#  'abettor',
#  'abevacuation',
#  'abey',
#  'abeyance',
#  'abeyancy',
#  'abeyant',
#  'abfarad',
#  'abhenry',
#  'abhiseka',
#  'abhominable',
#  'abhor',
#  'abhorrence',
#  'abhorrency',
#  'abhorrent',
#  'abhorrently',
#  'abhorrer',
#  'abhorrible',
#  'abhorring',
#  'abhorson',
#  'abidal',
#  'abidance',
#  'abide',
#  'abider',
#  'abidi',
#  'abiding',
#  'abidingly',
#  'abidingness',
#  'abie',
#  'abies',
#  'abietate',
#  'abietene',
#  'abietic',
#  'abietin',
#  'abietineae',
#  'abietineous',
#  'abietinic',
#  'abiezer',
#  'abigail',
#  'abigailship',
#  'abigeat',
#  'abigeus',
#  'abilao',
#  'ability',
#  'abilla',
#  'abilo',
#  'abintestate',
#  'abiogenesis',
#  'abiogenesist',
#  'abiogenetic',
#  'abiogenetical',
#  'abiogenetically',
#  'abiogenist',
#  'abiogenous',
#  'abiogeny',
#  'abiological',
#  'abiologically',
#  'abiology',
#  'abiosis',
#  'abiotic',
#  'abiotrophic',
#  'abiotrophy',
#  'abipon',
#  'abir',
#  'abirritant',
#  'abirritate',
#  'abirritation',
#  'abirritative',
#  'abiston',
#  'abitibi',
#  'abiuret',
#  'abject',
#  'abjectedness',
#  'abjection',
#  'abjective',
#  'abjectly',
#  'abjectness',
#  'abjoint',
#  'abjudge',
#  'abjudicate',
#  'abjudication',
#  'abjunction',
#  'abjunctive',
#  'abjuration',
#  'abjuratory',
#  'abjure',
#  'abjurement',
#  'abjurer',
#  'abkar',
#  'abkari',
#  'abkhas',
#  'abkhasian',
#  'ablach',
#  'ablactate',
#  'ablactation',
#  'ablare',
#  'ablastemic',
#  'ablastous',
#  'ablate',
#  'ablation',
#  'ablatitious',
#  'ablatival',
#  'ablative',
#  'ablator',
#  'ablaut',
#  'ablaze',
#  'able',
#  'ableeze',
#  'ablegate',
#  'ableness',
#  'ablepharia',
#  'ablepharon',
#  'ablepharous',
#  'ablepharus',
#  'ablepsia',
#  'ableptical',
#  'ableptically',
#  'abler',
#  'ablest',
#  'ablewhackets',
#  'ablins',
#  'abloom',
#  'ablow',
#  'ablude',
#  'abluent',
#  'ablush',
#  'ablution',
#  'ablutionary',
#  'abluvion',
#  'ably',
#  'abmho',
#  'abnaki',
#  'abnegate',
#  'abnegation',
#  'abnegative',
#  'abnegator',
#  'abner',
#  'abnerval',
#  'abnet',
#  'abneural',
#  'abnormal',
#  'abnormalism',
#  'abnormalist',
#  'abnormality',
#  'abnormalize',
#  'abnormally',
#  'abnormalness',
#  'abnormity',
#  'abnormous',
#  'abnumerable',
#  'abo',
#  'aboard',
#  'abobra',
#  'abode',
#  'abodement',
#  'abody',
#  'abohm',
#  'aboil',
#  'abolish',
#  'abolisher',
#  'abolishment',
#  'abolition',
#  'abolitionary',
#  'abolitionism',
#  'abolitionist',
#  'abolitionize',
#  'abolla',
#  'aboma',
#  'abomasum',
#  'abomasus',
#  'abominable',
#  'abominableness',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abominator',
#  'abomine',
#  'abongo',
#  'aboon',
#  'aborad',
#  'aboral',
#  'aborally',
#  'abord',
#  'aboriginal',
#  'aboriginality',
#  'aboriginally',
#  'aboriginary',
#  'aborigine',
#  'abort',
#  'aborted',
#  'aborticide',
#  'abortient',
#  'abortifacient',
#  'abortin',
#  'abortion',
#  'abortional',
#  'abortionist',
#  'abortive',
#  'abortively',
#  'abortiveness',
#  'abortus',
#  'abouchement',
#  'abound',
#  'abounder',
#  'abounding',
#  'aboundingly',
#  'about',
#  'abouts',
#  'above',
#  'aboveboard',
#  'abovedeck',
#  'aboveground',
#  'aboveproof',
#  'abovestairs',
#  'abox',
#  'abracadabra',
#  'abrachia',
#  'abradant',
#  'abrade',
#  'abrader',
#  'abraham',
#  'abrahamic',
#  'abrahamidae',
#  'abrahamite',
#  'abrahamitic',
#  'abraid',
#  'abram',
#  'abramis',
#  'abranchial',
#  'abranchialism',
#  'abranchian',
#  'abranchiata',
#  'abranchiate',
#  'abranchious',
#  'abrasax',
#  'abrase',
#  'abrash',
#  'abrasiometer',
#  'abrasion',
#  'abrasive',
#  'abrastol',
#  'abraum',
#  'abraxas',
#  'abreact',
#  'abreaction',
#  'abreast',
#  'abrenounce',
#  'abret',
#  'abrico',
#  'abridge',
#  'abridgeable',
#  'abridged',
#  'abridgedly',
#  'abridger',
#  'abridgment',
#  'abrim',
#  'abrin',
#  'abristle',
#  'abroach',
#  'abroad',
#  'abrocoma',
#  'abrocome',
#  'abrogable',
#  'abrogate',
#  'abrogation',
#  'abrogative',
#  'abrogator',
#  'abroma',
#  'abronia',
#  'abrook',
#  'abrotanum',
#  'abrotine',
#  'abrupt',
#  'abruptedly',
#  'abruption',
#  'abruptly',
#  'abruptness',
#  'abrus',
#  'absalom',
#  'absampere',
#  'absaroka',
#  'absarokite',
#  'abscess',
#  'abscessed',
#  'abscession',
#  'abscessroot',
#  'abscind',
#  'abscise',
#  'abscision',
#  'absciss',
#  'abscissa',
#  'abscissae',
#  'abscisse',
#  'abscission',
#  'absconce',
#  'abscond',
#  'absconded',
#  'abscondedly',
#  'abscondence',
#  'absconder',
#  'absconsa',
#  'abscoulomb',
#  'absence',
#  'absent',
#  'absentation',
#  'absentee',
#  'absenteeism',
#  'absenteeship',
#  'absenter',
#  'absently',
#  'absentment',
#  'absentmindedly',
#  'absentness',
#  'absfarad',
#  'abshenry',
#  'absi',
#  'absinthe',
#  'absinthial',
#  'absinthian',
#  'absinthiate',
#  'absinthic',
#  'absinthin',
#  'absinthine',
#  'absinthism',
#  'absinthismic',
#  'absinthium',
#  'absinthol',
#  'absit',
#  'absmho',
#  'absohm',
#  'absolute',
#  'absolutely',
#  'absoluteness',
#  'absolution',
#  'absolutism',
#  'absolutist',
#  'absolutistic',
#  'absolutistically',
#  'absolutive',
#  'absolutization',
#  'absolutize',
#  'absolutory',
#  'absolvable',
#  'absolvatory',
#  'absolve',
#  'absolvent',
#  'absolver',
#  'absolvitor',
#  'absolvitory',
#  'absonant',
#  'absonous',
#  'absorb',
#  'absorbability',
#  'absorbable',
#  'absorbed',
#  'absorbedly',
#  'absorbedness',
#  'absorbefacient',
#  'absorbency',
#  'absorbent',
#  'absorber',
#  'absorbing',
#  'absorbingly',
#  'absorbition',
#  'absorpt',
#  'absorptance',
#  'absorptiometer',
#  'absorptiometric',
#  'absorption',
#  'absorptive',
#  'absorptively',
#  'absorptiveness',
#  'absorptivity',
#  'absquatulate',
#  'abstain',
#  'abstainer',
#  'abstainment',
#  'abstemious',
#  'abstemiously',
#  'abstemiousness',
#  'abstention',
#  'abstentionist',
#  'abstentious',
#  'absterge',
#  'abstergent',
#  'abstersion',
#  'abstersive',
#  'abstersiveness',
#  'abstinence',
#  'abstinency',
#  'abstinent',
#  'abstinential',
#  'abstinently',
#  'abstract',
#  'abstracted',
#  'abstractedly',
#  'abstractedness',
#  'abstracter',
#  'abstraction',
#  'abstractional',
#  'abstractionism',
#  'abstractionist',
#  'abstractitious',
#  'abstractive',
#  'abstractively',
#  'abstractiveness',
#  'abstractly',
#  'abstractness',
#  'abstractor',
#  'abstrahent',
#  'abstricted',
#  'abstriction',
#  'abstruse',
#  'abstrusely',
#  'abstruseness',
#  'abstrusion',
#  'abstrusity',
#  'absume',
#  'absumption',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'absvolt',
#  'absyrtus',
#  'abterminal',
#  'abthain',
#  'abthainrie',
#  'abthainry',
#  'abthanage',
#  'abu',
#  'abucco',
#  'abulia',
#  'abulic',
#  'abulomania',
#  'abuna',
#  'abundance',
#  'abundancy',
#  'abundant',
#  'abundantia',
#  'abundantly',
#  'abura',
#  'aburabozu',
#  'aburban',
#  'aburst',
#  'aburton',
#  'abusable',
#  'abuse',
#  'abusedly',
#  'abusee',
#  'abuseful',
#  'abusefully',
#  'abusefulness',
#  'abuser',
#  'abusion',
#  'abusious',
#  'abusive',
#  'abusively',
#  'abusiveness',
#  'abut',
#  'abuta',
#  'abutilon',
#  'abutment',
#  'abuttal',
#  'abutter',
#  'abutting',
#  'abuzz',
#  'abvolt',
#  'abwab',
#  'aby',
#  'abysm',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'abyssal',
#  'abyssinian',
#  'abyssobenthonic',
#  'abyssolith',
#  'abyssopelagic',
#  'acacatechin',
#  'acacatechol',
#  'acacetin',
#  'acacia',
#  'acacian',
#  'acaciin',
#  'acacin',
#  'academe',
#  'academial',
#  'academian',
#  'academic',
#  'academical',
#  'academically',
#  'academicals',
#  'academician',
#  'academicism',
#  'academism',
#  'academist',
#  'academite',
#  'academization',
#  'academize',
#  'academus',
#  'academy',
#  'acadia',
#  'acadialite',
#  'acadian',
#  'acadie',
#  'acaena',
#  'acajou',
#  'acaleph',
#  'acalepha',
#  'acalephae',
#  'acalephan',
#  'acalephoid',
#  'acalycal',
#  'acalycine',
#  'acalycinous',
#  'acalyculate',
#  'acalypha',
#  'acalypterae',
#  'acalyptrata',
#  'acalyptratae',
#  'acalyptrate',
#  'acamar',
#  'acampsia',
#  'acana',
#  'acanaceous',
#  'acanonical',
#  'acanth',
#  'acantha',
#  'acanthaceae',
#  'acanthaceous',
#  'acanthad',
#  'acantharia',
#  'acanthia',
#  'acanthial',
#  'acanthin',
#  'acanthine',
#  'acanthion',
#  'acanthite',
#  'acanthocarpous',
#  'acanthocephala',
#  'acanthocephalan',
#  'acanthocephali',
#  'acanthocephalous',
#  'acanthocereus',
#  'acanthocladous',
#  'acanthodea',
#  'acanthodean',
#  'acanthodei',
#  'acanthodes',
#  'acanthodian',
#  'acanthodidae',
#  'acanthodii',
#  'acanthodini',
#  'acanthoid',
#  'acantholimon',
#  'acanthological',
#  'acanthology',
#  'acantholysis',
#  'acanthoma',
#  'acanthomeridae',
#  'acanthon',
#  'acanthopanax',
#  'acanthophis',
#  'acanthophorous',
#  'acanthopod',
#  'acanthopodous',
#  'acanthopomatous',
#  'acanthopore',
#  'acanthopteran',
#  'acanthopteri',
#  'acanthopterous',
#  'acanthopterygian',
#  'acanthopterygii',
#  'acanthosis',
#  'acanthous',
#  'acanthuridae',
#  'acanthurus',
#  'acanthus',
#  'acapnia',
#  'acapnial',
#  'acapsular',
#  'acapu',
#  'acapulco',
#  'acara',
#  'acarapis',
#  'acardia',
#  'acardiac',
#  'acari',
#  'acarian',
#  'acariasis',
#  'acaricidal',
#  'acaricide',
#  'acarid',
#  'acarida',
#  'acaridea',
#  'acaridean',
#  'acaridomatium',
#  'acariform',
#  'acarina',
#  'acarine',
#  'acarinosis',
#  'acarocecidium',
#  'acarodermatitis',
#  'acaroid',
#  'acarol',
#  'acarologist',
#  'acarology',
#  'acarophilous',
#  'acarophobia',
#  'acarotoxic',
#  'acarpelous',
#  'acarpous',
#  'acarus',
#  'acastus',
#  'acatalectic',
#  'acatalepsia',
#  'acatalepsy',
#  'acataleptic',
#  'acatallactic',
#  'acatamathesia',
#  'acataphasia',
#  'acataposis',
#  'acatastasia',
#  'acatastatic',
#  'acate',
#  'acategorical',
#  'acatery',
#  'acatharsia',
#  'acatharsy',
#  'acatholic',
#  'acaudal',
#  'acaudate',
#  'acaulescent',
#  'acauline',
#  'acaulose',
#  'acaulous',
#  'acca',
#  'accede',
#  'accedence',
#  'acceder',
#  'accelerable',
#  'accelerando',
#  'accelerant',
#  'accelerate',
#  'accelerated',
#  'acceleratedly',
#  'acceleration',
#  'accelerative',
#  'accelerator',
#  'acceleratory',
#  'accelerograph',
#  'accelerometer',
#  'accend',
#  'accendibility',
#  'accendible',
#  'accension',
#  'accensor',
#  'accent',
#  'accentless',
#  'accentor',
#  'accentuable',
#  'accentual',
#  'accentuality',
#  'accentually',
#  'accentuate',
#  'accentuation',
#  'accentuator',
#  'accentus',
#  'accept',
#  'acceptability',
#  'acceptable',
#  'acceptableness',
#  'acceptably',
#  'acceptance',
#  'acceptancy',
#  'acceptant',
#  'acceptation',
#  'accepted',
#  'acceptedly',
#  'accepter',
#  'acceptilate',
#  'acceptilation',
#  'acception',
#  'acceptive',
#  'acceptor',
#  'acceptress',
#  'accerse',
#  'accersition',
#  'accersitor',
#  'access',
#  'accessarily',
#  'accessariness',
#  'accessary',
#  'accessaryship',
#  'accessibility',
#  'accessible',
#  'accessibly',
#  'accession',
#  'accessional',
#  'accessioner',
#  'accessive',
#  'accessively',
#  'accessless',
#  'accessorial',
#  'accessorily',
#  'accessoriness',
#  'accessorius',
#  'accessory',
#  'accidence',
#  'accidency',
#  'accident',
#  'accidental',
#  'accidentalism',
#  'accidentalist',
#  'accidentality',
#  'accidentally',
#  'accidentalness',
#  'accidented',
#  'accidential',
#  'accidentiality',
#  'accidently',
#  'accidia',
#  'accidie',
#  'accinge',
#  'accipient',
#  'accipiter',
#  'accipitral',
#  'accipitrary',
#  'accipitres',
#  'accipitrine',
#  'accismus',
#  'accite',
#  'acclaim',
#  'acclaimable',
#  'acclaimer',
#  'acclamation',
#  'acclamator',
#  'acclamatory',
#  'acclimatable',
#  'acclimatation',
#  'acclimate',
#  'acclimatement',
#  'acclimation',
#  'acclimatizable',
#  'acclimatization',
#  'acclimatize',
#  'acclimatizer',
#  'acclimature',
#  'acclinal',
#  'acclinate',
#  'acclivitous',
#  'acclivity',
#  'acclivous',
#  'accloy',
#  'accoast',
#  'accoil',
#  'accolade',
#  'accoladed',
#  'accolated',
#  'accolent',
#  'accolle',
#  'accombination',
#  'accommodable',
#  'accommodableness',
#  'accommodate',
#  'accommodately',
#  'accommodateness',
#  'accommodating',
#  'accommodatingly',
#  'accommodation',
#  'accommodational',
#  'accommodative',
#  'accommodativeness',
#  'accommodator',
#  'accompanier',
#  'accompaniment',
#  'accompanimental',
#  'accompanist',
#  'accompany',
#  'accompanyist',
#  'accompletive',
#  'accomplice',
#  'accompliceship',
#  'accomplicity',
#  'accomplish',
#  'accomplishable',
#  'accomplished',
#  'accomplisher',
#  'accomplishment',
#  'accomplisht',
#  'accompt',
#  'accord',
#  'accordable',
#  'accordance',
#  'accordancy',
#  'accordant',
#  'accordantly',
#  'accorder',
#  'according',
#  'accordingly',
#  'accordion',
#  ...]

# %%
wordclean = [word.strip().lower() for word in open('words','r')]

# %%
wordclean = [word.strip().lower() for word in open('words','r')]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordclean = set([word.strip().lower() for word in open('words','r')])

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('words','r')])))

# %%
wordclean
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
#  'abashedness',
#  'abashless',
#  'abashlessly',
#  'abashment',
#  'abasia',
#  'abasic',
#  'abask',
#  'abassin',
#  'abastardize',
#  'abatable',
#  'abate',
#  'abatement',
#  'abater',
#  'abatis',
#  'abatised',
#  'abaton',
#  'abator',
#  'abattoir',
#  'abatua',
#  'abature',
#  'abave',
#  'abaxial',
#  'abaxile',
#  'abaze',
#  'abb',
#  'abba',
#  'abbacomes',
#  'abbacy',
#  'abbadide',
#  'abbas',
#  'abbasi',
#  'abbassi',
#  'abbasside',
#  'abbatial',
#  'abbatical',
#  'abbess',
#  'abbey',
#  'abbeystede',
#  'abbie',
#  'abbot',
#  'abbotcy',
#  'abbotnullius',
#  'abbotship',
#  'abbreviate',
#  'abbreviately',
#  'abbreviation',
#  'abbreviator',
#  'abbreviatory',
#  'abbreviature',
#  'abby',
#  'abcoulomb',
#  'abdal',
#  'abdat',
#  'abderian',
#  'abderite',
#  'abdest',
#  'abdicable',
#  'abdicant',
#  'abdicate',
#  'abdication',
#  'abdicative',
#  'abdicator',
#  'abdiel',
#  'abditive',
#  'abditory',
#  'abdomen',
#  'abdominal',
#  'abdominales',
#  'abdominalian',
#  'abdominally',
#  'abdominoanterior',
#  'abdominocardiac',
#  'abdominocentesis',
#  'abdominocystic',
#  'abdominogenital',
#  'abdominohysterectomy',
#  'abdominohysterotomy',
#  'abdominoposterior',
#  'abdominoscope',
#  'abdominoscopy',
#  'abdominothoracic',
#  'abdominous',
#  'abdominovaginal',
#  'abdominovesical',
#  'abduce',
#  'abducens',
#  'abducent',
#  'abduct',
#  'abduction',
#  'abductor',
#  'abe',
#  'abeam',
#  'abear',
#  'abearance',
#  'abecedarian',
#  'abecedarium',
#  'abecedary',
#  'abed',
#  'abeigh',
#  'abel',
#  'abele',
#  'abelia',
#  'abelian',
#  'abelicea',
#  'abelite',
#  'abelmoschus',
#  'abelmosk',
#  'abelonian',
#  'abeltree',
#  'abencerrages',
#  'abenteric',
#  'abepithymia',
#  'aberdeen',
#  'aberdevine',
#  'aberdonian',
#  'aberia',
#  'aberrance',
#  'aberrancy',
#  'aberrant',
#  'aberrate',
#  'aberration',
#  'aberrational',
#  'aberrator',
#  'aberrometer',
#  'aberroscope',
#  'aberuncator',
#  'abet',
#  'abetment',
#  'abettal',
#  'abettor',
#  'abevacuation',
#  'abey',
#  'abeyance',
#  'abeyancy',
#  'abeyant',
#  'abfarad',
#  'abhenry',
#  'abhiseka',
#  'abhominable',
#  'abhor',
#  'abhorrence',
#  'abhorrency',
#  'abhorrent',
#  'abhorrently',
#  'abhorrer',
#  'abhorrible',
#  'abhorring',
#  'abhorson',
#  'abidal',
#  'abidance',
#  'abide',
#  'abider',
#  'abidi',
#  'abiding',
#  'abidingly',
#  'abidingness',
#  'abie',
#  'abies',
#  'abietate',
#  'abietene',
#  'abietic',
#  'abietin',
#  'abietineae',
#  'abietineous',
#  'abietinic',
#  'abiezer',
#  'abigail',
#  'abigailship',
#  'abigeat',
#  'abigeus',
#  'abilao',
#  'ability',
#  'abilla',
#  'abilo',
#  'abintestate',
#  'abiogenesis',
#  'abiogenesist',
#  'abiogenetic',
#  'abiogenetical',
#  'abiogenetically',
#  'abiogenist',
#  'abiogenous',
#  'abiogeny',
#  'abiological',
#  'abiologically',
#  'abiology',
#  'abiosis',
#  'abiotic',
#  'abiotrophic',
#  'abiotrophy',
#  'abipon',
#  'abir',
#  'abirritant',
#  'abirritate',
#  'abirritation',
#  'abirritative',
#  'abiston',
#  'abitibi',
#  'abiuret',
#  'abject',
#  'abjectedness',
#  'abjection',
#  'abjective',
#  'abjectly',
#  'abjectness',
#  'abjoint',
#  'abjudge',
#  'abjudicate',
#  'abjudication',
#  'abjunction',
#  'abjunctive',
#  'abjuration',
#  'abjuratory',
#  'abjure',
#  'abjurement',
#  'abjurer',
#  'abkar',
#  'abkari',
#  'abkhas',
#  'abkhasian',
#  'ablach',
#  'ablactate',
#  'ablactation',
#  'ablare',
#  'ablastemic',
#  'ablastous',
#  'ablate',
#  'ablation',
#  'ablatitious',
#  'ablatival',
#  'ablative',
#  'ablator',
#  'ablaut',
#  'ablaze',
#  'able',
#  'ableeze',
#  'ablegate',
#  'ableness',
#  'ablepharia',
#  'ablepharon',
#  'ablepharous',
#  'ablepharus',
#  'ablepsia',
#  'ableptical',
#  'ableptically',
#  'abler',
#  'ablest',
#  'ablewhackets',
#  'ablins',
#  'abloom',
#  'ablow',
#  'ablude',
#  'abluent',
#  'ablush',
#  'ablution',
#  'ablutionary',
#  'abluvion',
#  'ably',
#  'abmho',
#  'abnaki',
#  'abnegate',
#  'abnegation',
#  'abnegative',
#  'abnegator',
#  'abner',
#  'abnerval',
#  'abnet',
#  'abneural',
#  'abnormal',
#  'abnormalism',
#  'abnormalist',
#  'abnormality',
#  'abnormalize',
#  'abnormally',
#  'abnormalness',
#  'abnormity',
#  'abnormous',
#  'abnumerable',
#  'abo',
#  'aboard',
#  'abobra',
#  'abode',
#  'abodement',
#  'abody',
#  'abohm',
#  'aboil',
#  'abolish',
#  'abolisher',
#  'abolishment',
#  'abolition',
#  'abolitionary',
#  'abolitionism',
#  'abolitionist',
#  'abolitionize',
#  'abolla',
#  'aboma',
#  'abomasum',
#  'abomasus',
#  'abominable',
#  'abominableness',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abominator',
#  'abomine',
#  'abongo',
#  'aboon',
#  'aborad',
#  'aboral',
#  'aborally',
#  'abord',
#  'aboriginal',
#  'aboriginality',
#  'aboriginally',
#  'aboriginary',
#  'aborigine',
#  'abort',
#  'aborted',
#  'aborticide',
#  'abortient',
#  'abortifacient',
#  'abortin',
#  'abortion',
#  'abortional',
#  'abortionist',
#  'abortive',
#  'abortively',
#  'abortiveness',
#  'abortus',
#  'abouchement',
#  'abound',
#  'abounder',
#  'abounding',
#  'aboundingly',
#  'about',
#  'abouts',
#  'above',
#  'aboveboard',
#  'abovedeck',
#  'aboveground',
#  'aboveproof',
#  'abovestairs',
#  'abox',
#  'abracadabra',
#  'abrachia',
#  'abradant',
#  'abrade',
#  'abrader',
#  'abraham',
#  'abrahamic',
#  'abrahamidae',
#  'abrahamite',
#  'abrahamitic',
#  'abraid',
#  'abram',
#  'abramis',
#  'abranchial',
#  'abranchialism',
#  'abranchian',
#  'abranchiata',
#  'abranchiate',
#  'abranchious',
#  'abrasax',
#  'abrase',
#  'abrash',
#  'abrasiometer',
#  'abrasion',
#  'abrasive',
#  'abrastol',
#  'abraum',
#  'abraxas',
#  'abreact',
#  'abreaction',
#  'abreast',
#  'abrenounce',
#  'abret',
#  'abrico',
#  'abridge',
#  'abridgeable',
#  'abridged',
#  'abridgedly',
#  'abridger',
#  'abridgment',
#  'abrim',
#  'abrin',
#  'abristle',
#  'abroach',
#  'abroad',
#  'abrocoma',
#  'abrocome',
#  'abrogable',
#  'abrogate',
#  'abrogation',
#  'abrogative',
#  'abrogator',
#  'abroma',
#  'abronia',
#  'abrook',
#  'abrotanum',
#  'abrotine',
#  'abrupt',
#  'abruptedly',
#  'abruption',
#  'abruptly',
#  'abruptness',
#  'abrus',
#  'absalom',
#  'absampere',
#  'absaroka',
#  'absarokite',
#  'abscess',
#  'abscessed',
#  'abscession',
#  'abscessroot',
#  'abscind',
#  'abscise',
#  'abscision',
#  'absciss',
#  'abscissa',
#  'abscissae',
#  'abscisse',
#  'abscission',
#  'absconce',
#  'abscond',
#  'absconded',
#  'abscondedly',
#  'abscondence',
#  'absconder',
#  'absconsa',
#  'abscoulomb',
#  'absence',
#  'absent',
#  'absentation',
#  'absentee',
#  'absenteeism',
#  'absenteeship',
#  'absenter',
#  'absently',
#  'absentment',
#  'absentmindedly',
#  'absentness',
#  'absfarad',
#  'abshenry',
#  'absi',
#  'absinthe',
#  'absinthial',
#  'absinthian',
#  'absinthiate',
#  'absinthic',
#  'absinthin',
#  'absinthine',
#  'absinthism',
#  'absinthismic',
#  'absinthium',
#  'absinthol',
#  'absit',
#  'absmho',
#  'absohm',
#  'absolute',
#  'absolutely',
#  'absoluteness',
#  'absolution',
#  'absolutism',
#  'absolutist',
#  'absolutistic',
#  'absolutistically',
#  'absolutive',
#  'absolutization',
#  'absolutize',
#  'absolutory',
#  'absolvable',
#  'absolvatory',
#  'absolve',
#  'absolvent',
#  'absolver',
#  'absolvitor',
#  'absolvitory',
#  'absonant',
#  'absonous',
#  'absorb',
#  'absorbability',
#  'absorbable',
#  'absorbed',
#  'absorbedly',
#  'absorbedness',
#  'absorbefacient',
#  'absorbency',
#  'absorbent',
#  'absorber',
#  'absorbing',
#  'absorbingly',
#  'absorbition',
#  'absorpt',
#  'absorptance',
#  'absorptiometer',
#  'absorptiometric',
#  'absorption',
#  'absorptive',
#  'absorptively',
#  'absorptiveness',
#  'absorptivity',
#  'absquatulate',
#  'abstain',
#  'abstainer',
#  'abstainment',
#  'abstemious',
#  'abstemiously',
#  'abstemiousness',
#  'abstention',
#  'abstentionist',
#  'abstentious',
#  'absterge',
#  'abstergent',
#  'abstersion',
#  'abstersive',
#  'abstersiveness',
#  'abstinence',
#  'abstinency',
#  'abstinent',
#  'abstinential',
#  'abstinently',
#  'abstract',
#  'abstracted',
#  'abstractedly',
#  'abstractedness',
#  'abstracter',
#  'abstraction',
#  'abstractional',
#  'abstractionism',
#  'abstractionist',
#  'abstractitious',
#  'abstractive',
#  'abstractively',
#  'abstractiveness',
#  'abstractly',
#  'abstractness',
#  'abstractor',
#  'abstrahent',
#  'abstricted',
#  'abstriction',
#  'abstruse',
#  'abstrusely',
#  'abstruseness',
#  'abstrusion',
#  'abstrusity',
#  'absume',
#  'absumption',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'absvolt',
#  'absyrtus',
#  'abterminal',
#  'abthain',
#  'abthainrie',
#  'abthainry',
#  'abthanage',
#  'abu',
#  'abucco',
#  'abulia',
#  'abulic',
#  'abulomania',
#  'abuna',
#  'abundance',
#  'abundancy',
#  'abundant',
#  'abundantia',
#  'abundantly',
#  'abura',
#  'aburabozu',
#  'aburban',
#  'aburst',
#  'aburton',
#  'abusable',
#  'abuse',
#  'abusedly',
#  'abusee',
#  'abuseful',
#  'abusefully',
#  'abusefulness',
#  'abuser',
#  'abusion',
#  'abusious',
#  'abusive',
#  'abusively',
#  'abusiveness',
#  'abut',
#  'abuta',
#  'abutilon',
#  'abutment',
#  'abuttal',
#  'abutter',
#  'abutting',
#  'abuzz',
#  'abvolt',
#  'abwab',
#  'aby',
#  'abysm',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'abyssal',
#  'abyssinian',
#  'abyssobenthonic',
#  'abyssolith',
#  'abyssopelagic',
#  'acacatechin',
#  'acacatechol',
#  'acacetin',
#  'acacia',
#  'acacian',
#  'acaciin',
#  'acacin',
#  'academe',
#  'academial',
#  'academian',
#  'academic',
#  'academical',
#  'academically',
#  'academicals',
#  'academician',
#  'academicism',
#  'academism',
#  'academist',
#  'academite',
#  'academization',
#  'academize',
#  'academus',
#  'academy',
#  'acadia',
#  'acadialite',
#  'acadian',
#  'acadie',
#  'acaena',
#  'acajou',
#  'acaleph',
#  'acalepha',
#  'acalephae',
#  'acalephan',
#  'acalephoid',
#  'acalycal',
#  'acalycine',
#  'acalycinous',
#  'acalyculate',
#  'acalypha',
#  'acalypterae',
#  'acalyptrata',
#  'acalyptratae',
#  'acalyptrate',
#  'acamar',
#  'acampsia',
#  'acana',
#  'acanaceous',
#  'acanonical',
#  'acanth',
#  'acantha',
#  'acanthaceae',
#  'acanthaceous',
#  'acanthad',
#  'acantharia',
#  'acanthia',
#  'acanthial',
#  'acanthin',
#  'acanthine',
#  'acanthion',
#  'acanthite',
#  'acanthocarpous',
#  'acanthocephala',
#  'acanthocephalan',
#  'acanthocephali',
#  'acanthocephalous',
#  'acanthocereus',
#  'acanthocladous',
#  'acanthodea',
#  'acanthodean',
#  'acanthodei',
#  'acanthodes',
#  'acanthodian',
#  'acanthodidae',
#  'acanthodii',
#  'acanthodini',
#  'acanthoid',
#  'acantholimon',
#  'acanthological',
#  'acanthology',
#  'acantholysis',
#  'acanthoma',
#  'acanthomeridae',
#  'acanthon',
#  'acanthopanax',
#  'acanthophis',
#  'acanthophorous',
#  'acanthopod',
#  'acanthopodous',
#  'acanthopomatous',
#  'acanthopore',
#  'acanthopteran',
#  'acanthopteri',
#  'acanthopterous',
#  'acanthopterygian',
#  'acanthopterygii',
#  'acanthosis',
#  'acanthous',
#  'acanthuridae',
#  'acanthurus',
#  'acanthus',
#  'acapnia',
#  'acapnial',
#  'acapsular',
#  'acapu',
#  'acapulco',
#  'acara',
#  'acarapis',
#  'acardia',
#  'acardiac',
#  'acari',
#  'acarian',
#  'acariasis',
#  'acaricidal',
#  'acaricide',
#  'acarid',
#  'acarida',
#  'acaridea',
#  'acaridean',
#  'acaridomatium',
#  'acariform',
#  'acarina',
#  'acarine',
#  'acarinosis',
#  'acarocecidium',
#  'acarodermatitis',
#  'acaroid',
#  'acarol',
#  'acarologist',
#  'acarology',
#  'acarophilous',
#  'acarophobia',
#  'acarotoxic',
#  'acarpelous',
#  'acarpous',
#  'acarus',
#  'acastus',
#  'acatalectic',
#  'acatalepsia',
#  'acatalepsy',
#  'acataleptic',
#  'acatallactic',
#  'acatamathesia',
#  'acataphasia',
#  'acataposis',
#  'acatastasia',
#  'acatastatic',
#  'acate',
#  'acategorical',
#  'acatery',
#  'acatharsia',
#  'acatharsy',
#  'acatholic',
#  'acaudal',
#  'acaudate',
#  'acaulescent',
#  'acauline',
#  'acaulose',
#  'acaulous',
#  'acca',
#  'accede',
#  'accedence',
#  'acceder',
#  'accelerable',
#  'accelerando',
#  'accelerant',
#  'accelerate',
#  'accelerated',
#  'acceleratedly',
#  'acceleration',
#  'accelerative',
#  'accelerator',
#  'acceleratory',
#  'accelerograph',
#  'accelerometer',
#  'accend',
#  'accendibility',
#  'accendible',
#  'accension',
#  'accensor',
#  'accent',
#  'accentless',
#  'accentor',
#  'accentuable',
#  'accentual',
#  'accentuality',
#  'accentually',
#  'accentuate',
#  'accentuation',
#  'accentuator',
#  'accentus',
#  'accept',
#  'acceptability',
#  'acceptable',
#  'acceptableness',
#  'acceptably',
#  'acceptance',
#  'acceptancy',
#  'acceptant',
#  'acceptation',
#  'accepted',
#  'acceptedly',
#  'accepter',
#  'acceptilate',
#  'acceptilation',
#  'acception',
#  'acceptive',
#  'acceptor',
#  'acceptress',
#  'accerse',
#  'accersition',
#  'accersitor',
#  'access',
#  'accessarily',
#  'accessariness',
#  'accessary',
#  'accessaryship',
#  'accessibility',
#  'accessible',
#  'accessibly',
#  'accession',
#  'accessional',
#  'accessioner',
#  'accessive',
#  'accessively',
#  'accessless',
#  'accessorial',
#  'accessorily',
#  'accessoriness',
#  'accessorius',
#  'accessory',
#  'accidence',
#  'accidency',
#  'accident',
#  'accidental',
#  'accidentalism',
#  'accidentalist',
#  'accidentality',
#  'accidentally',
#  'accidentalness',
#  'accidented',
#  'accidential',
#  'accidentiality',
#  'accidently',
#  'accidia',
#  'accidie',
#  'accinge',
#  'accipient',
#  'accipiter',
#  'accipitral',
#  'accipitrary',
#  'accipitres',
#  'accipitrine',
#  'accismus',
#  'accite',
#  'acclaim',
#  'acclaimable',
#  'acclaimer',
#  'acclamation',
#  'acclamator',
#  'acclamatory',
#  'acclimatable',
#  'acclimatation',
#  'acclimate',
#  'acclimatement',
#  'acclimation',
#  'acclimatizable',
#  'acclimatization',
#  'acclimatize',
#  'acclimatizer',
#  'acclimature',
#  'acclinal',
#  'acclinate',
#  'acclivitous',
#  'acclivity',
#  'acclivous',
#  'accloy',
#  'accoast',
#  'accoil',
#  'accolade',
#  'accoladed',
#  'accolated',
#  'accolent',
#  'accolle',
#  'accombination',
#  'accommodable',
#  'accommodableness',
#  'accommodate',
#  'accommodately',
#  'accommodateness',
#  'accommodating',
#  'accommodatingly',
#  'accommodation',
#  'accommodational',
#  'accommodative',
#  'accommodativeness',
#  'accommodator',
#  'accompanier',
#  'accompaniment',
#  'accompanimental',
#  'accompanist',
#  'accompany',
#  'accompanyist',
#  'accompletive',
#  'accomplice',
#  'accompliceship',
#  'accomplicity',
#  'accomplish',
#  'accomplishable',
#  'accomplished',
#  'accomplisher',
#  'accomplishment',
#  'accomplisht',
#  'accompt',
#  'accord',
#  'accordable',
#  'accordance',
#  'accordancy',
#  'accordant',
#  'accordantly',
#  'accorder',
#  'according',
#  'accordingly',
#  'accordion',
#  ...]
